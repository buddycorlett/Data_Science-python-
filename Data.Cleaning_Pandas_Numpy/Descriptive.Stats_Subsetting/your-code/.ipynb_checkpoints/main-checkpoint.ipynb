# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
temp = pd.read_csv('Temp_States.csv')
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.dtypes
#City is an object which holds a string
#State is an object which holds a string
#Temperature is a float value
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
temp[temp.State == "New York"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1f76650f10b2> in <module>
# ----> 1 temp[temp.State == "New York"].temp.mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'temp'

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
temp1 = temp[temp.State == "New York"]

# %%
temp1['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
temp2 = temp[temp.Temperature > 15]
temp2[["City","Temperature"]]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
temp3 = temp[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]['City']
print(temp3)
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# import statistics as stat

# states = list(temp.State.unique())
# print(states)
# ny_temp = []
# con_temp = []
# nj_temp = []



# for i in range(len(temp['State'])):
#     if temp['State'][i] == 'New York': 
#         ny_temp.append(temp['Temperature'][i])
#     elif temp['State'][i] == 'Connecticut': 
#         con_temp.append(temp['Temperature'][i])
#     elif temp['State'][i] == 'New Jersey': 
#         nj_temp.append(temp['Temperature'][i])

# #for i in range(len(states)): 

# print("the Standard Deviation for NY is " + str(stat.stdev(ny_temp)))
# print("the Standard Deviation for Conn is " + str(stat.stdev(con_temp)))
# print("the Standard Deviation for NJ is " + str(stat.stdev(nj_temp)))
# print("the mean for NY is " + str(stat.mean(ny_temp)))
# print("the mean for Conn is " + str(stat.mean(con_temp)))
# print("the mean for NJ is " + str(stat.mean(nj_temp)))

temp5 = temp.groupby('State', as_index=False).agg({'Temperature':['mean',"std"]})
temp5
# Out:
#          State Temperature
#                       mean       std
# 0  Connecticut   15.833333  1.964186
# 1   New Jersey   21.111111  1.571348
# 2     New York   10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv("employee.csv")
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee.dtypes
#Name is a string object
#Department is a string object
#Education is a string object
#Gender is a string object
#Title is a string object
#Years is an integer
#Salary is an integer
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
print(pd.DataFrame.hist(employee))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000239F8A09D68>
# ...

# %% [markdown]
# #### What's the average salary in this company?

# %%
pd.DataFrame.mean(employee['Salary'])
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
pd.DataFrame.max(employee['Salary'])
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
pd.DataFrame.min(employee['Salary'])
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
for i in range(len(employee['Salary'])):
    if employee['Salary'][i] == pd.DataFrame.min(employee['Salary']):
        print(employee['Name'][i])
        print(employee['Salary'][i])
# temp_minsal = employee[employee["Salary"] == employee["Salary"].min()]   
# print(temp_minsal)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
david_df = employee[employee['Name']== "David"]
print(david_df)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# david_salary = employee[employee['Name'] == "David"]['Salary']
# david_salary

david_salary = employee.loc[employee["Name"]== "David",["Salary","Name"]]
david_salary
# Out:
#    Salary   Name
# 2      30  David

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
associate = employee.loc[employee["Title"] == "associate", :]
associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# employee[:3]
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
ass_over55 = employee[(employee['Title']== 'associate') & (employee['Salary'] > 55)]
ass_over55
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
yoe = employee.sort_values('Years')
yoe_mean = employee.groupby('Years', as_index=False).agg({'Salary':['mean']})
yoe_mean
# Out:
#   Years     Salary
#               mean
# 0     1  35.000000
# 1     2  38.333333
# 2     3  55.000000
# 3     4  35.000000
# 4     7  60.000000
# 5     8  70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
yoe_title = employee.groupby('Title', as_index=False).agg({'Salary':['mean']})
yoe_title
# Out:
#        Title     Salary
#                    mean
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
boxplot_years = employee.boxplot("Years")
boxplot_salary = employee.boxplot("Salary")

# %%
employee.quantile(.25)
# employee.quantile(.25)["Years"]
# employee.quantile(.25)["Salary"]
# # employee.describe()
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
employee.quantile(.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
gender_mean = employee.groupby('Gender', as_index=False).agg({'Salary':['mean']})
gender_mean
#Yes lower for women
# Out:
#   Gender Salary
#            mean
# 0      F   47.5
# 1      M   50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
employee.groupby("Department").agg({"Years":["mean","max",'min'], "Salary":["mean","max",'min']})
# Out:
#                Years         Salary
#                 mean max min   mean max min
# Department
# HR          4.666667   8   2  45.00  70  30
# IT          4.500000   8   1  48.75  70  30
# Sales       2.500000   3   2  55.00  55  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('Orders/Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# 5                5     536365     22752  2010     12    3     8
# 6                6     536365     21730  2010     12    3     8
# 7                7     536366     22633  2010     12    3     8
# 8                8     536366     22632  2010     12    3     8
# 9                9     536367     84879  2010     12    3     8
# 10              10     536367     22745  2010     12    3     8
# 11              11     536367     22748  2010     12    3     8
# 12              12     536367     22749  2010     12    3     8
# 13              13     536367     22310  2010     12    3     8
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders.describe()["UnitPrice"]['mean']
# Out:
# 22.39474850474768

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders.describe()["UnitPrice"]['min']
# Out:
# 0.0

# %%
orders.describe()["UnitPrice"]['max']
# Out:
# 8142.75

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
spanish_custs = orders[(orders['Country'] == 'Spain')] 
spanish_custs
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 13974        21565     538095     22504  2010     12    4    14
# 13975        21566     538095     22212  2010     12    4    14
# 13976        21567     538095     22953  2010     12    4    14
# 13977        21568     538095     84818  2010     12    4    14
# 13978        21569     538095     21114  2010     12    4    14
# 13979        21570     538095     84692  2010     12    4    14
# 13980        21571     538095     22796  2010     12    4    14
# 13981        21572     538095     40001  2010     12    4    14
# 13982        21573     538095     22646  2010     12    4    14
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
orders["Country"].value_counts()['Spain']
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
more50_t = orders.groupby("CustomerID").agg({"Quantity":["sum"]})
more50 = more50_t[(more50_t['Quantity']['sum'] > 50)]
more50


# more50_t["Quantity"]["sum"]

# more50_t.columns
# Out:
#            Quantity
#                 sum
# CustomerID
# 12346         74215
# 12347          2458
# 12348          2341
# 12349           631
# 12350           197
# 12352           536
# 12354           530
# 12355           240
# 12356          1591
# 12357          2708
# 12358           248
# 12359          1622
# 12360          1165
# 12361            91
# 12362          2229
# 12363           408
# 12364          1506
# 12365           174
# 12367           173
# 12370          2353
# 12371           591
# 12372           794
# 12373           197
# 12374           342
# 12375           178
# 12377           944
# 12378          2529
# 12379           407
# 12380          1127
# 12381           808
# ...             ...
# 18240           126
# 18241          1051
# 18242          1017
# 18245          1788
# 18246           166
# 18248           511
# 18249           128
# 18250           199
# 18251          7824
# 18252           239
# 18255            74
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
span50_t = spanish_custs.groupby("CustomerID").agg({"Quantity":["sum"]})
span50 = span50_t[(span50_t['Quantity']['sum'] > 50)]
span50
# Out:
#            Quantity
#                 sum
# CustomerID
# 12354           530
# 12417           267
# 12421           484
# 12442           182
# 12445            62
# 12448           243
# 12450           128
# 12454          1006
# 12455           566
# 12462           536
# 12484          2191
# 12502           820
# 12507           905
# 12510           353
# 12538           191
# 12539          2067
# 12540          6685
# 12541           680
# 12544           136
# 12545           523
# 12546           633
# 12547           134
# 12550           569
# 12551           100
# 12556           358
# 12557          4384
# 12596           474
# 12597          2236
# 17097           459

# %% [markdown]
# #### Select all free orders

# %%
free_items = orders[(orders['UnitPrice']== 0)]
free_items
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
lunch_bag = orders[(orders['Description'].str.contains("lunch bag" or "Lunch bag" or "Lunch Bag" or "lunch Bag")'associate')
lunch_bag
# Out:
#   File "<ipython-input-344-04caa6d8aac2>", line 1
#     lunch_bag = orders[(orders['Description'].str.contains("lunch bag" or "Lunch bag" or "Lunch Bag" or "lunch Bag")'associate')
#                                                                                                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
