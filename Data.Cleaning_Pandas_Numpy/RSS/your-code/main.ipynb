# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser as fp
import pandas as pd

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
oreily = fp.parse(url)
oreily
# Out:
# {'feed': {'title': 'Radar',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Radar'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.oreilly.com/radar'},
#    {'rel': 'self',
#     'type': 'application/rss+xml',
#     'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'link': 'https://www.oreilly.com/radar',
#   'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'},
#   'updated': 'Wed, 18 Sep 2019 11:48:50 +0000',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=18, tm_hour=11, tm_min=48, tm_sec=50, tm_wday=2, tm_yday=261, tm_isdst=0),
#   'language': 'en-US',
#   'sy_updateperiod': 'hourly',
#   'sy_updatefrequency': '1',
#   'generator_detail': {'name': 'https://wordpress.org/?v=5.2.3'},
#   'generator': 'https://wordpress.org/?v=5.2.3',
#   'feedburner_info': {'uri': 'oreilly/radar/atom'},
#   'geo_lat': '38.393314',
#   'geo_long': '-122.836667',
#   'feedburner_emailserviceid': 'oreilly/radar/atom',
#   'feedburner_feedburnerhostname': 'https://feedburner.google.com'},
#  'entries': [{'title': 'Four short links: 18 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 18 September 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/A6f_aG1aRUc/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/A6f_aG1aRUc/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-18-september-2019/#respond',
#    'published': 'Wed, 18 Sep 2019 04:01:52 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=18, tm_hour=4, tm_min=1, tm_sec=52, tm_wday=2, tm_yday=261, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9372',
#    'guidislink': False,
#    'summary': 'Extracting Insights from the Shape of Complex Data using Topology (Nature) — three properties of topology that make it useful: coordinate-free, so you can work on data with different coordinate systems; &#8220;small&#8221; deformation invariance, so it&#8217;s resistant to some forms of noise; and it works on the compressed representations of shapes so you can use [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Extracting Insights from the Shape of Complex Data using Topology (Nature) — three properties of topology that make it useful: coordinate-free, so you can work on data with different coordinate systems; &#8220;small&#8221; deformation invariance, so it&#8217;s resistant to some forms of noise; and it works on the compressed representations of shapes so you can use [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol>\n<li><a href="https://www.nature.com/articles/srep01236">Extracting Insights from the Shape of Complex Data using Topology</a> (Nature) — three properties of topology that make it useful: coordinate-free, so you can work on data with different coordinate systems; &#8220;small&#8221; deformation invariance, so it&#8217;s resistant to some forms of noise; and it works on the compressed representations of shapes so you can use it to throw away features but still keep fundamental properties of the shape of the data. I&#8217;m paraphrasing the intro here.</li>\n<li><a href="https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3427110">Getting Tired of Your Friends: The Dynamics of Venture Capital Relationships</a> — <i>Based on the relationships of the top 50 US venture capital firms, this paper focuses on the strengths of relationships and their dynamic evolution. Empirical estimates indicate that having a deeper relationship leads to fewer, not more future co-investments. Moreover, deeper relationships lead to lower exit performance, even after controlling for endogeneity. Interestingly, deeper relationships first lead to lower performance, and subsequently lead to a slowdown in the relationship intensity.</i> The more I know about you, the less I want to do business with you because I know we&#8217;ll lose money together.</li>\n<li><a href="https://imagenet-roulette.paglen.com/">ImageNet Roulette</a> (Kate Crawford and Trevor Paglen) — show it a picture, it&#8217;ll label using ImageNet. A wonderful reality check about the limitations of general-purpose computer perception.</li>\n<li><a href="https://socialscience.one/files/partnershipone/files/facebook_urls-light_codebook_v2.0.pdf">Social Science One Ships</a> — Facebook&#8217;s project to release data to registered researchers took longer than expected because they implemented differential privacy (perturbing the data to preserve statistical properties while preventing reconstruction of any one person&#8217;s attributes). <i>The data describe web page addresses (URLs) that have been shared on Facebook starting January 1, 2017, up to and including February 19, 2019. URLs are included if shared with public privacy settings more than on average 100 times (±Laplace(5) noise to minimize information leakage). We have conducted post-processing on the URLs &#8230; to remove potentially private and/or sensitive data</i> This paper goes into detail on steps taken to protect privacy.</li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/A6f_aG1aRUc" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-18-september-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-18-september-2019/'},
#   {'title': 'Four short links: 17 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 17 September 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/3sl4sS_qiyM/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/3sl4sS_qiyM/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-17-september-2019/#respond',
#    'published': 'Tue, 17 Sep 2019 04:01:36 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=17, tm_hour=4, tm_min=1, tm_sec=36, tm_wday=1, tm_yday=260, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9350',
#    'guidislink': False,
#    'summary': 'Mirroring to Build Trust in Digital Assistants — these experiments are designed to measure whether users prefer and trust an assistant whose conversational style matches their own. To this end, we conducted a user study where subjects interacted with a digital assistant that responded in a way that either matched their conversational style, or did [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Mirroring to Build Trust in Digital Assistants — these experiments are designed to measure whether users prefer and trust an assistant whose conversational style matches their own. To this end, we conducted a user study where subjects interacted with a digital assistant that responded in a way that either matched their conversational style, or did [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol>\n<li><a href="https://arxiv.org/abs/1904.01664">Mirroring to Build Trust in Digital Assistants</a> — <i>these experiments are designed to measure whether users prefer and trust an assistant whose conversational style matches their own. To this end, we conducted a user study where subjects interacted with a digital assistant that responded in a way that either matched their conversational style, or did not. Using self-reported personality attributes and subjects&#8217; feedback on the interactions, we built models that can reliably predict a user&#8217;s preferred conversational style.</i></li>\n<li><a href="https://twitter.com/julien_c/status/1173669642629537795">Apple, Are You Trying to Bankrupt Us?</a> (@julien_c) — make sure your CI system caches its dependencies.</li>\n<li><a href="https://www.cs.mcgill.ca/~jpineau/ReproducibilityChecklist.pdf">Reproducibility Checklist</a> — very sensible measures being required for some AI journals now. (via <a href="https://www.wired.com/story/artificial-intelligence-confronts-reproducibility-crisis/">Wired</a>)</li>\n<li><a href="https://nullroute.eu.org/~grawity/startkeylogger.html">DCC SEND startkeylogger</a> — my new favorite example of why you have to be aware of the cost of false positives, not just of false negatives. Most people can see the sense in, &#8220;it&#8217;d be bad to let a command-and-control server talk to an infected machine,&#8221; and can&#8217;t see the risk in, &#8220;so kill any connection that looks like it&#8217;s a C&amp;C server talking to an infected machine&#8221;.</li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/3sl4sS_qiyM" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-17-september-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-17-september-2019/'},
#   {'title': 'Four short links: 16 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 16 September 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/xhx_x7ZXwyU/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/xhx_x7ZXwyU/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-16-september-2019/#respond',
#    'published': 'Mon, 16 Sep 2019 04:01:02 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=16, tm_hour=4, tm_min=1, tm_sec=2, tm_wday=0, tm_yday=259, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9320',
#    'guidislink': False,
#    'summary': 'Challenges in the Decentralised Web: The Mastodon Case &#8212; We found that Mastodon’s design decision of giving everyone the ability to establish an independent instance of their own has led to an active ecosystem, with instances covering a wide variety of topics. However, a common theme in our work has been the discovery of apparent [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Challenges in the Decentralised Web: The Mastodon Case &#8212; We found that Mastodon’s design decision of giving everyone the ability to establish an independent instance of their own has led to an active ecosystem, with instances covering a wide variety of topics. However, a common theme in our work has been the discovery of apparent [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol>\n<li><a href="https://emilianodc.com/PAPERS/mastodonIMC19.pdf">Challenges in the Decentralised Web: The Mastodon Case</a> &#8212; <i>We found that Mastodon’s design decision of giving everyone the ability to establish an independent instance of their own has led to an active ecosystem, with instances covering a wide variety of topics. However, a common theme in our work has been the discovery of apparent forms of centralisation within Mastodon. For example, 10% of instances host almost half of the users, and certain categories exhibit remarkable reliance on a small set of instances. This extends to hosting practices, with three ASes hosting almost two-thirds of the users.</i> (via <a href="https://twitter.com/emilianoucl/status/1172187384710139905">@emilianoucl</a>)</li>\n<li><a href="http://ucbvislab.github.io/d3-deconstructor/">D3 Deconstructor</a> &#8212; get the data out of D3 visualisations. (via <a href="https://twitter.com/lisacrost/status/1172163711013924870">Lisa Charlotte Rost</a>)</li>\n<li><a href="https://github.com/medialab/zup">zup</a> &#8212; <i>a simple interface from extracting texts from (almost) any url. (via <a href="https://twitter.com/pinardag/status/1172198796937314306">Pınar Dağ Firth</a>)</i></li>\n<p><i></i></p>\n<p><i></i></p>\n<p><i></i></p>\n<p><i></i></p>\n<p><i></p>\n<li><a href="http://www.zephoria.org/thoughts/archives/2019/09/15/facing-the-great-reckoning-head-on.html">Facing the Great Reckoning Head On</a> (danah boyd) &#8212; <i>The Great Reckoning is in front of us. How we respond to the calls for justice will shape the future of technology and society. We must hold accountable all who perpetuate, amplify, and enable hate, harm, and cruelty. But accountability without transformation is simply spectacle. We owe it to ourselves and to all of those who have been hurt to focus on the root of the problem. We also owe it to them to actively seek to not build certain technologies because the human cost is too great.</i></li>\n<p></i><i></i><i></i><i></i><i></i></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/xhx_x7ZXwyU" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-16-september-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-16-september-2019/'},
#   {'title': 'Radar trends to watch: September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Radar trends to watch: September 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/OZcMhIWV22I/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/OZcMhIWV22I/',
#    'comments': 'https://www.oreilly.com/radar/radar-trends-to-watch-september-2019/#respond',
#    'published': 'Fri, 13 Sep 2019 04:02:19 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=4, tm_min=2, tm_sec=19, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Radar Trends', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9078',
#    'guidislink': False,
#    'summary': 'Radar trends began as an internal resource for O’Reilly. It’s a monthly list of things that I find interesting or important—possibly not “trends,” strictly understood, but ideas that might become trends. Most items on the list have links to media sources—some original sources, more frequently other reporting, whichever I think is more informative. Some items [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Radar trends began as an internal resource for O’Reilly. It’s a monthly list of things that I find interesting or important—possibly not “trends,” strictly understood, but ideas that might become trends. Most items on the list have links to media sources—some original sources, more frequently other reporting, whichever I think is more informative. Some items [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>Radar trends began as an internal resource for O’Reilly. It’s a monthly list of things that I find interesting or important—possibly not “trends,” strictly understood, but ideas that might become trends.</p>\n<p>Most items on the list have links to media sources—some original sources, more frequently other reporting, whichever I think is more informative. Some items are personal observations or summaries of interesting conversations.</p>\n<p>Many items are about technology, conceived rather broadly. Over time, topics will include biology and biotech, design and user experience, ethics, open source communities, energy, and more.</p>\n<p>We hope you find these observations useful and informative!</p>\n<h2>AI trends</h2>\n<p>Germany, France, and Japan have <a href="https://www.insidehighered.com/news/2019/08/23/new-research-alliance-cements-split-ai-ethics">formed an alliance</a> for “human-centered” AI. Canada is also a potential member. This move is partially to get them “critical mass” in AI research, rather than coming off in third place, and partially because they don’t trust ethical stances in the US and China, and they see a market opportunity for ethical AI.</p>\n<p><a href="https://blog.hackster.io/machine-learning-for-creators-d420f9e592e3">RunwayML</a> is yet another entry in the “create a deep learning model with minimal programming” sweepstakes. Jeremy Howard’s platform.ai sounds the most radical; there’s also AI2GO (from xnor.ai), AutoML (from Google Cloud Platform), and others. Are we on the edge of programmerless AI? Is this Software 2.0?</p>\n<p>Cerebras has announced a <a href="https://techcrunch.com/2019/08/19/the-five-technical-challenges-cerebras-overcame-in-building-the-first-trillion-transistor-chip/">trillion transistor chip</a>. It’s by far the largest chip ever marketed (roughly the size of a sheet of paper), and it’s designed for training AI systems. Although it has huge power requirements (15 KW), it probably makes AI development less power hungry, and certainly less time consuming. In the long run, this probably doesn’t address the problem of power consumption; given faster, more powerful processors, people will create bigger, more complex models.</p>\n<p>We’ve seen <a href="https://www.snorkel.org/">Snorkel</a> (now a <a href="https://www.snorkel.ai/">startup</a>) and the other tools from Chris Ré’s lab at Stanford. <a href="https://www.bloomberg.com/news/articles/2019-08-05/scale-ai-is-silicon-valley-s-latest-unicorn">Scale AI</a> appears to be doing something similar (partially automated image tagging, though it still uses contract workers on the back end). This is an important step in the democratization of AI. As Ré <a href="https://learning.oreilly.com/videos/artificial-intelligence-conference/9781492050544/9781492050544-video324795">said</a> at the O’Reilly Artificial Intelligence Conference in New York, data collection and model building have largely been automated, but data tagging and cleaning are stubbornly dependent on human labor.</p>\n<h2>Security trends</h2>\n<p>The Linux Foundation’s <a href="https://thenewstack.io/linux-foundation-forms-the-confidential-computing-consortium-to-protect-data-in-use/">Confidential Computing Consortium</a> aims to protect data that is in use–i.e., data that is being computed on, not data at rest (in storage) or in flight (being transferred). This requires a combination of hardware and software to build a trusted computing environment. It has significant backing from Intel, Microsoft, and Red Hat/IBM.</p>\n<p><a href="https://arstechnica.com/information-technology/2019/08/the-year-long-rash-of-supply-chain-attacks-against-open-source-is-getting-worse/">Supply chain attacks</a> aren’t entirely new, but they’re becoming more common. The idea is to attack the open source supply chain: find a project that isn’t well managed (of which there are many), and submit changes that create a backdoor that can be exploited in other projects that includ ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/radar-trends-to-watch-september-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/radar-trends-to-watch-september-2019/'},
#   {'title': 'Four short links: 13 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 13 September 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/bGzHnB1Ldfk/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/bGzHnB1Ldfk/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-13-september-2019/#respond',
#    'published': 'Fri, 13 Sep 2019 04:00:56 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=4, tm_min=0, tm_sec=56, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9304',
#    'guidislink': False,
#    'summary': 'Universal Adversarial Triggers for Attacking and Analyzing NLP &#8212; WARNING: This paper contains model outputs which are offensive in nature. How to make small changes to the input text used to build a model, causing large downstream changes in its accuracy. (via Nasty Language Processing: Textual Triggers Transform Bots Into Bigots) AP Data Kit &#8212; [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Universal Adversarial Triggers for Attacking and Analyzing NLP &#8212; WARNING: This paper contains model outputs which are offensive in nature. How to make small changes to the input text used to build a model, causing large downstream changes in its accuracy. (via Nasty Language Processing: Textual Triggers Transform Bots Into Bigots) AP Data Kit &#8212; [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol>\n<li><a href="https://arxiv.org/pdf/1908.07125.pdf">Universal Adversarial Triggers for Attacking and Analyzing NLP</a> &#8212; <i>WARNING: This paper contains model outputs which are offensive in nature.</i> How to make small changes to the input text used to build a model, causing large downstream changes in its accuracy. (via <a href="https://medium.com/syncedreview/nasty-language-processing-textual-triggers-transform-bots-into-bigots-25f99b5a633">Nasty Language Processing: Textual Triggers Transform Bots Into Bigots</a>)</li>\n<li><a href="http://datakit.ap.org/">AP Data Kit</a> &#8212; <i>an open-source command-line tool designed to better structure and manage projects. It makes it easier to standardize and share work among members of your team, and to keep your past projects organized and easily accessible for future reference. AP DataKit works off a basic framework that includes the core product and a few key plugins to help you manage where your data files and code are stored and updated.</i></li>\n<li><a href="https://www.scottaaronson.com/blog/?p=4301">Quantum Computing and the Fundamental Limits of Computation</a> (Scott Aaronson) &#8212; three lectures: <em>The Church-Turing Thesis and Physics</em> (<a href="https://video.ethz.ch/speakers/bernays/2019/7b11b50e-f813-4d26-95e0-616cc350708c.html">watch</a>, <a href="https://www.scottaaronson.com/talks/bernays1.ppt">PPT</a>), <em>The Limits of Efficient Computation</em> (<a href="https://video.ethz.ch/speakers/bernays/2019/5564a353-d71b-46d4-bfc0-fa907de5de25.html">watch</a>, <a href="https://www.scottaaronson.com/talks/bernays2.ppt">PPT</a>), and <em>The Quest for Quantum Computational Supremacy</em> (<a href="https://video.ethz.ch/speakers/bernays/2019/2a08c4a0-67e1-4e1f-8019-3e557fcb4cde.html">watch</a>, <a href="https://www.scottaaronson.com/talks/bernays3.ppt">PPT</a>).</li>\n<li><a href="https://arxiv.org/abs/1909.04739">WIQA</a> &#8212; <i>the first large-scale dataset of &#8220;What if&#8230;&#8221; questions over procedural text. WIQA contains three parts: a collection of paragraphs each describing a process, e.g., beach erosion; a set of crowdsourced influence graphs for each paragraph, describing how one change affects another; and a large (40k) collection of &#8220;What if&#8230;?&#8221; multiple-choice questions derived from the graphs. [&#8230;] WIQA contains three kinds of questions: perturbations to steps mentioned in the paragraph; external (out-of-paragraph) perturbations requiring commonsense knowledge; and irrelevant (no effect) perturbations.</i></li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/bGzHnB1Ldfk" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-13-september-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-13-september-2019/'},
#   {'title': 'Safe and smarter driving, powered by AI',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Safe and smarter driving, powered by AI'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/l1xGG-1JLLE/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/l1xGG-1JLLE/',
#    'comments': 'https://www.oreilly.com/radar/safe-and-smarter-driving-powered-by-ai/#respond',
#    'published': 'Fri, 13 Sep 2019 01:00:27 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=1, tm_min=0, tm_sec=27, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9335',
#    'guidislink': False,
#    'summary': 'This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. See other highlights from the event. This keynote was sponsored by Amazon Web Services.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. See other highlights from the event. This keynote was sponsored by Amazon Web Services.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">See other highlights from the event</a>.</p>\n<p><em>This keynote was sponsored by Amazon Web Services.</em></p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/l1xGG-1JLLE" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/safe-and-smarter-driving-powered-by-ai/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/safe-and-smarter-driving-powered-by-ai/'},
#   {'title': 'On gradient-based methods for finding game-theoretic equilibria',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'On gradient-based methods for finding game-theoretic equilibria'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ub1hZ9yYRXU/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ub1hZ9yYRXU/',
#    'comments': 'https://www.oreilly.com/radar/on-gradient-based-methods-for-finding-game-theoretic-equilibria/#respond',
#    'published': 'Fri, 13 Sep 2019 00:00:58 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=58, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9148',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326797">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ub1hZ9yYRXU" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/on-gradient-based-methods-for-finding-game-theoretic-equilibria/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/on-gradient-based-methods-for-finding-game-theoretic-equilibria/'},
#   {'title': 'Accelerate with purpose',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Accelerate with purpose'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/7mEwqcHDq8w/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/7mEwqcHDq8w/',
#    'comments': 'https://www.oreilly.com/radar/accelerate-with-purpose/#respond',
#    'published': 'Fri, 13 Sep 2019 00:00:45 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=45, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9154',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326754">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/7mEwqcHDq8w" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/accelerate-with-purpose/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/accelerate-with-purpose/'},
#   {'title': 'Practical insights into deep reinforcement learning',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Practical insights into deep reinforcement learning'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/iQjrpmHS5h0/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/iQjrpmHS5h0/',
#    'comments': 'https://www.oreilly.com/radar/practical-insights-into-deep-reinforcement-learning/#respond',
#    'published': 'Fri, 13 Sep 2019 00:00:42 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=42, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9162',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326778">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/iQjrpmHS5h0" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/practical-insights-into-deep-reinforcement-learning/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/practical-insights-into-deep-reinforcement-learning/'},
#   {'title': 'Open-endedness: A new grand challenge for AI',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Open-endedness: A new grand challenge for AI'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/kqeKo5uttuc/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/kqeKo5uttuc/',
#    'comments': 'https://www.oreilly.com/radar/open-endedness-a-new-grand-challenge-for-ai/#respond',
#    'published': 'Fri, 13 Sep 2019 00:00:22 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=22, tm_wday=4, tm_yday=256, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9168',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326784">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/kqeKo5uttuc" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/open-endedness-a-new-grand-challenge-for-ai/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/open-endedness-a-new-grand-challenge-for-ai/'},
#   {'title': 'Four short links: 12 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 12 September 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/gbtXRIuaLgw/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/gbtXRIuaLgw/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-12-september-2019/#respond',
#    'published': 'Thu, 12 Sep 2019 08:00:56 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=12, tm_hour=8, tm_min=0, tm_sec=56, tm_wday=3, tm_yday=255, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9249',
#    'guidislink': False,
#    'summary': 'The Philosophy and Practice of Bayesian Statistics — A substantial school in the philosophy of science identifies Bayesian inference with inductive inference and even rationality as such, and seems to be strengthened by the rise and practical success of Bayesian statistics. We argue that the most successful forms of Bayesian statistics do not actually support [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The Philosophy and Practice of Bayesian Statistics — A substantial school in the philosophy of science identifies Bayesian inference with inductive inference and even rationality as such, and seems to be strengthened by the rise and practical success of Bayesian statistics. We argue that the most successful forms of Bayesian statistics do not actually support [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol>\n<li><a href="http://www.stat.columbia.edu/~gelman/research/published/philosophy.pdf">The Philosophy and Practice of Bayesian Statistics</a> — <i>A substantial school in the philosophy of science identifies Bayesian inference with inductive inference and even rationality as such, and seems to be strengthened by the rise and practical success of Bayesian statistics. We argue that the most successful forms of Bayesian statistics do not actually support that particular philosophy but rather accord much better with sophisticated forms of hypothetico-deductivism [&#8230;] Clarity about these matters should benefit not just philosophy of science, but also statistical practice. At best, the inductivist view has encouraged researchers to fit and compare models without checking them; at worst, theorists have actively discouraged practitioners from performing model checking because it does not fit into their framework.</i></li>\n<li><a href="https://www.youtube.com/watch?v=E18shi1qIHU">Erlang, or How I Learned to Stop Worrying and Let Things Fail</a> (John Daily) — talk from 2014 that highlights how it&#8217;s not just one killer feature that makes Erlang work so well for its problem domain, but rather it&#8217;s how features work so well together. A thought for language and product designers everywhere.</li>\n<li><a href="https://esolangs.org/wiki/Quantum_INTERCAL">Quantum INTERCAL</a> — INTERCAL is a <a href="https://en.wikipedia.org/wiki/INTERCAL">parody programming language</a> (<i>The full name of the compiler is &#8220;Compiler Language With No Pronounceable Acronym,&#8221; which is, for obvious reasons, abbreviated &#8220;INTERCAL.&#8221;</i>), and this page proposes quantum computing extensions for it. I love this kind of whimsy, and hope our industry doesn&#8217;t lose it.</li>\n<li><a href="https://www.nature.com/articles/s41562-018-0474-5">The Universal Decay of Memory and Attention</a> (Nature) — <i>Our results reveal that biographies remain in our communicative memory the longest (20–30\u2009years) and music the shortest (about 5.6\u2009years). These findings show that the average attention received by cultural products decays following a universal biexponential function.</i> Mysteriously fails to cover the incredible vanishing act of new people&#8217;s names in my brain. (And previously-known people&#8217;s names)</li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/gbtXRIuaLgw" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-12-september-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-12-september-2019/'},
#   {'title': 'AI for ophthalmology: Doing what doctors can’t',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'AI for ophthalmology: Doing what doctors can’t'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/oiMXLozH0I8/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/oiMXLozH0I8/',
#    'comments': 'https://www.oreilly.com/radar/ai-for-opthalmology-doing-what-doctors-cant/#respond',
#    'published': 'Thu, 12 Sep 2019 02:00:20 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=12, tm_hour=2, tm_min=0, tm_sec=20, tm_wday=3, tm_yday=255, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9131',
#    'guidislink': False,
#    'summary': 'This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. See other highlights from the event. This keynote was sponsored by Dell Technologies.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. See other highlights from the event. This keynote was sponsored by Dell Technologies.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">See other highlights from the event</a>.</p>\n<p><em>This keynote was sponsored by Dell Technologies.</em></p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/oiMXLozH0I8" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/ai-for-opthalmology-doing-what-doctors-cant/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/ai-for-opthalmology-doing-what-doctors-cant/'},
#   {'title': 'Enabling AI’s potential through wafer-scale integration',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Enabling AI’s potential through wafer-scale integration'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/R8FDgHpYdWY/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/R8FDgHpYdWY/',
#    'comments': 'https://www.oreilly.com/radar/enabling-ais-potential-through-wafer-scale-integration/#respond',
#    'published': 'Thu, 12 Sep 2019 01:00:56 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=12, tm_hour=1, tm_min=0, tm_sec=56, tm_wday=3, tm_yday=255, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9123',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
# ...
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326757">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/pxw9TMGo_BM" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/getting-from-a-to-ai/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/getting-from-a-to-ai/'},
#   {'title': 'Highlights from the O’Reilly Artificial Intelligence Conference in San Jose 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Highlights from the O’Reilly Artificial Intelligence Conference in San Jose 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/IuxUBAbXJxo/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/IuxUBAbXJxo/',
#    'comments': 'https://www.oreilly.com/radar/highlights-from-ai-sj-2019/#respond',
#    'published': 'Thu, 12 Sep 2019 00:00:49 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=12, tm_hour=0, tm_min=0, tm_sec=49, tm_wday=3, tm_yday=255, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9176',
#    'guidislink': False,
#    'summary': 'People from across artificial intelligence (AI) world came together in San Jose, Calif. for the O&#8217;Reilly Artificial Intelligence Conference. Below you&#8217;ll find links to highlights from the event. Open-endedness: A new grand challenge for AI Kenneth Stanley discusses how open-ended algorithms can offer an entirely different level of automated creation. Watch &#8220;Open-endedness: A new grand [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'People from across artificial intelligence (AI) world came together in San Jose, Calif. for the O&#8217;Reilly Artificial Intelligence Conference. Below you&#8217;ll find links to highlights from the event. Open-endedness: A new grand challenge for AI Kenneth Stanley discusses how open-ended algorithms can offer an entirely different level of automated creation. Watch &#8220;Open-endedness: A new grand [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>People from across artificial intelligence (AI) world came together in San Jose, Calif. for the <a href="https://conferences.oreilly.com/artificial-intelligence/ai-ca">O&#8217;Reilly Artificial Intelligence Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>Open-endedness: A new grand challenge for AI</h2>\n<p>Kenneth Stanley discusses how open-ended algorithms can offer an entirely different level of automated creation.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/open-endedness-a-new-grand-challenge-for-ai">Open-endedness: A new grand challenge for AI</a>&#8220;</li>\n</ul>\n<h2>Going beyond fully supervised learning</h2>\n<p>Srinivas Narayanan takes a deep look into the next change we’re seeing in AI—going beyond fully supervised learning techniques.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/going-beyond-fully-supervised-learning">Going beyond fully supervised learning</a>&#8220;</li>\n</ul>\n<h2>Practical insights into deep reinforcement learning</h2>\n<p>Sahika Genc dives deep into state-of-the-art techniques in deep reinforcement learning for a variety of use cases.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/practical-insights-into-deep-reinforcement-learning">Practical insights into deep reinforcement learning</a>&#8220;</li>\n</ul>\n<h2>Enabling AI’s potential through wafer-scale integration</h2>\n<p>Andrew Feldman discusses the Wafer Scale Engine, the largest chip ever built.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/enabling-ais-potential-through-wafer-scale-integration">Enabling AI’s potential through wafer-scale integration</a>&#8220;</li>\n</ul>\n<h2>On gradient-based methods for finding game-theoretic equilibria</h2>\n<p>Michael Jordan details several recent results that blend gradient-based methodology with game-theoretic goals.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/on-gradient-based-methods-for-finding-game-theoretic-equilibria">On gradient-based methods for finding game-theoretic equilibria</a>&#8220;</li>\n</ul>\n<h2>Getting from A to AI</h2>\n<p>Eric Gardner shares a four-step journey that all kinds of organizations can use to evaluate their unique paths from data to insights.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/getting-from-a-to-ai">Getting from A to AI</a>&#8220;</li>\n</ul>\n<h2>Developing AI responsibly</h2>\n<p>Sarah Bird discusses the major challenges of responsible AI development and examines promising new tools and technologies to help enable it in practice.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/developing-ai-responsibly">Developing AI responsibly</a>&#8220;</li>\n</ul>\n<h2>Accelerate with purpose</h2>\n<p>Ananth Sankaranarayanan discusses three three key shifts in the AI landscape, how to navigate them, and when to explore hardware acceleration.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/accelerate-with-purpose">Accelerate with purpose</a>&#8220;</li>\n</ul>\n<h2>Unlocking the value of your data</h2>\n<p>Dinesh Nirmal examines how organizations can unlock the value of their data for AI with a unified, prescriptive information architecture.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/unlocking-the-value-of-your-data">Unlocking the value of your data</a>&#8220;</li>\n</ul>\n<h2>Safe and smarter driving, powered by AI</h2>\n<p>Lei Pan explores how Nauto uses AWS to continually evolve smarter data for driver behavior.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/safe-and-smarter-driving-powered-by-ai">Safe and smarter driving, powered by AI</a>&#8220;</li>\n</ul>\n<h2>AI for ophthalmology: Doing what doctors can’t</h2>\n<p>Daniel Russakoff discusses how AI is being used to predict age-related macular degeneration progression.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/ai-for-opt ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-ai-sj-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-ai-sj-2019/'},
#   {'title': 'Going beyond fully supervised learning',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Going beyond fully supervised learning'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wUUF4YFvifU/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wUUF4YFvifU/',
#    'comments': 'https://www.oreilly.com/radar/going-beyond-fully-supervised-learning/#respond',
#    'published': 'Wed, 11 Sep 2019 22:00:17 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=11, tm_hour=22, tm_min=0, tm_sec=17, tm_wday=2, tm_yday=254, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9142',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326790">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/wUUF4YFvifU" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/going-beyond-fully-supervised-learning/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/going-beyond-fully-supervised-learning/'},
#   {'title': 'Developing AI responsibly',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Developing AI responsibly'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/uVuAjgcqig8/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/uVuAjgcqig8/',
#    'comments': 'https://www.oreilly.com/radar/developing-ai-responsibly/#respond',
#    'published': 'Wed, 11 Sep 2019 13:00:41 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=41, tm_wday=2, tm_yday=254, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9112',
#    'guidislink': False,
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://learning.oreilly.com/videos/oreilly-artificial-intelligence/9781492050667/9781492050667-video326647">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/uVuAjgcqig8" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/developing-ai-responsibly/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/developing-ai-responsibly/'},
#   {'title': 'Unlocking the value of your data',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Unlocking the value of your data'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/LF-87yH-5tc/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/LF-87yH-5tc/',
#    'comments': 'https://www.oreilly.com/radar/unlocking-the-value-of-your-data/#respond',
#    'published': 'Wed, 11 Sep 2019 13:00:38 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=38, tm_wday=2, tm_yday=254, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=9106',
#    'guidislink': False,
#    'summary': 'This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. See other highlights from the event. This keynote was sponsored by IBM Watson.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. See other highlights from the event. This keynote was sponsored by IBM Watson.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from the O&#8217;Reilly Artificial Intelligence Conference in San Jose 2019. <a href="https://www.oreilly.com/radar/highlights-from-ai-sj-2019">See other highlights from the event</a>.</p>\n<p><em>This keynote was sponsored by IBM Watson.</em></p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/LF-87yH-5tc" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/unlocking-the-value-of-your-data/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/unlocking-the-value-of-your-data/'}],
#  'bozo': 0,
#  'headers': {'Content-Type': 'text/xml; charset=UTF-8',
#   'ETag': '3KZY5CvctYmu3ILff8Y28b83quI',
#   'Last-Modified': 'Wed, 18 Sep 2019 12:53:53 GMT',
#   'Content-Encoding': 'gzip',
#   'Transfer-Encoding': 'chunked',
#   'Date': 'Wed, 18 Sep 2019 14:02:18 GMT',
#   'Expires': 'Wed, 18 Sep 2019 14:02:18 GMT',
#   'Cache-Control': 'private, max-age=0',
#   'X-Content-Type-Options': 'nosniff',
#   'X-XSS-Protection': '1; mode=block',
#   'Server': 'GSE',
#   'Connection': 'close'},
#  'etag': '3KZY5CvctYmu3ILff8Y28b83quI',
#  'updated': 'Wed, 18 Sep 2019 12:53:53 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=18, tm_hour=12, tm_min=53, tm_sec=53, tm_wday=2, tm_yday=261, tm_isdst=0),
#  'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {'content': 'http://purl.org/rss/1.0/modules/content/',
#   'wfw': 'http://wellformedweb.org/CommentAPI/',
#   'dc': 'http://purl.org/dc/elements/1.1/',
#   '': 'http://www.w3.org/2005/Atom',
#   'sy': 'http://purl.org/rss/1.0/modules/syndication/',
#   'slash': 'http://purl.org/rss/1.0/modules/slash/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'feedburner': 'http://rssnamespace.org/feedburner/ext/1.0'}}

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
oreily.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
oreily.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print(oreily.feed.title)
print(oreily.feed.subtitle)
print(oreily.entries[10].author)
print(oreily.feed.link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# Mac Slocum
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
df = pd.DataFrame(oreily.entries)
df.count()
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#        author  entries
# 0  Mac Slocum       18

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
oreily.entries[0].keys()
# for names in oreily.keys():
#     print(oreily.names.keys())
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [oreily.entries[i].title for i in range(len(oreily.entries))]
titles
# Out:
# ['Four short links: 18 September 2019',
#  'Four short links: 17 September 2019',
#  'Four short links: 16 September 2019',
#  'Radar trends to watch: September 2019',
#  'Four short links: 13 September 2019',
#  'Safe and smarter driving, powered by AI',
#  'On gradient-based methods for finding game-theoretic equilibria',
#  'Accelerate with purpose',
#  'Practical insights into deep reinforcement learning',
#  'Open-endedness: A new grand challenge for AI',
#  'Four short links: 12 September 2019',
#  'AI for ophthalmology: Doing what doctors can’t',
#  'Enabling AI’s potential through wafer-scale integration',
#  'Getting from A to AI',
#  'Highlights from the O’Reilly Artificial Intelligence Conference in San Jose 2019',
#  'Going beyond fully supervised learning',
#  'Developing AI responsibly',
#  'Unlocking the value of your data']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
import re
pattern = 'Four short links'

string_titles = ' '.join(titles)

x = re.findall(pattern,string_titles)

j = 0
for i in range(len(x)):
    j+=1

print(str((j/len(titles))*100) + "%")
# Out:
# 27.77777777777778%

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(oreily.entries)
df
# Out:
#         author           author_detail                   authors  \
# 0   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 1   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 2   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 3   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 4   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 5   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 6   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 7   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 8   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 9   Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 10  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 11  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 12  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 13  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 14  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 15  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 16  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
# 17  Mac Slocum  {'name': 'Mac Slocum'}  [{'name': 'Mac Slocum'}]
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/four-short-links...
# 1   https://www.oreilly.com/radar/four-short-links...
# 2   https://www.oreilly.com/radar/four-short-links...
# 3   https://www.oreilly.com/radar/radar-trends-to-...
# 4   https://www.oreilly.com/radar/four-short-links...
# 5   https://www.oreilly.com/radar/safe-and-smarter...
# 6   https://www.oreilly.com/radar/on-gradient-base...
# 7   https://www.oreilly.com/radar/accelerate-with-...
# 8   https://www.oreilly.com/radar/practical-insigh...
# 9   https://www.oreilly.com/radar/open-endedness-a...
# 10  https://www.oreilly.com/radar/four-short-links...
# 11  https://www.oreilly.com/radar/ai-for-opthalmol...
# 12  https://www.oreilly.com/radar/enabling-ais-pot...
# 13  https://www.oreilly.com/radar/getting-from-a-t...
# 14  https://www.oreilly.com/radar/highlights-from-...
# 15  https://www.oreilly.com/radar/going-beyond-ful...
# 16  https://www.oreilly.com/radar/developing-ai-re...
# 17  https://www.oreilly.com/radar/unlocking-the-va...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
#
#                                   feedburner_origlink  guidislink  \
# 0   https://www.oreilly.com/radar/four-short-links...       False
# 1   https://www.oreilly.com/radar/four-short-links...       False
# 2   https://www.oreilly.com/radar/four-short-links...       False
# 3   https://www.oreilly.com/radar/radar-trends-to-...       False
# 4   https://www.oreilly.com/radar/four-short-links...       False
# 5   https://www.oreilly.com/radar/safe-and-smarter...       False
# 6   https://www.oreilly.com/radar/on-gradient-base...       False
# 7   https://www.oreilly.com/radar/accelerate-with-...       False
# 8   https://www.oreilly.com/radar/practical-insigh...       False
# 9   https://www.oreilly.com/radar/open-endedness-a...       False
# 10  https://www.oreilly.com/radar/four-short-links...       False
# 11  https://www.oreilly.com/radar/ai-for-opthalmol...       False
# 12  https://www.oreilly.com/radar/enabling-ais-pot...       False
# 13  https://www.oreilly.com/radar/getting-from-a-t...       False
# 14  https://www.oreilly.com/radar/highlights-from-...       False
# 15  https://www.oreilly.com/radar/going-beyond-ful...       False
# 16  https://www.oreilly.com/radar/developing-ai-re...       False
# 17  https://www.oreilly.com/radar/unlocking-the-va...       False
#
#                                        id  \
# 0   https://www.oreilly.com/radar/?p=9372
# 1   https://www.oreilly.com/radar/?p=9350
# 2   https://www.oreilly.com/radar/?p=9320
# 3   https://www.oreilly.com/radar/?p=9078
# 4   https://www.oreilly.com/radar/?p=9304
# 5   https://www.oreilly.com/radar/?p=9335
# 6   https://www.oreilly.com/radar/?p=9148
# 7   https://www.oreilly.com/radar/?p=9154
# 8   https://www.oreilly.com/radar/?p=9162
# 9   https://www.oreilly.com/radar/?p=9168
# 10  https://www.oreilly.com/radar/?p=9249
# 11  https://www.oreilly.com/radar/?p=9131
# 12  https://www.oreilly.com/radar/?p=9123
# 13  https://www.oreilly.com/radar/?p=9100
# 14  https://www.oreilly.com/radar/?p=9176
# 15  https://www.oreilly.com/radar/?p=9142
# 16  https://www.oreilly.com/radar/?p=9112
# 17  https://www.oreilly.com/radar/?p=9106
#
#                                                  link  \
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 15  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 17  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                           published                     published_parsed  \
# 0   Wed, 18 Sep 2019 04:01:52 +0000   (2019, 9, 18, 4, 1, 52, 2, 261, 0)
# 1   Tue, 17 Sep 2019 04:01:36 +0000   (2019, 9, 17, 4, 1, 36, 1, 260, 0)
# 2   Mon, 16 Sep 2019 04:01:02 +0000    (2019, 9, 16, 4, 1, 2, 0, 259, 0)
# 3   Fri, 13 Sep 2019 04:02:19 +0000   (2019, 9, 13, 4, 2, 19, 4, 256, 0)
# 4   Fri, 13 Sep 2019 04:00:56 +0000   (2019, 9, 13, 4, 0, 56, 4, 256, 0)
# 5   Fri, 13 Sep 2019 01:00:27 +0000   (2019, 9, 13, 1, 0, 27, 4, 256, 0)
# 6   Fri, 13 Sep 2019 00:00:58 +0000   (2019, 9, 13, 0, 0, 58, 4, 256, 0)
# 7   Fri, 13 Sep 2019 00:00:45 +0000   (2019, 9, 13, 0, 0, 45, 4, 256, 0)
# 8   Fri, 13 Sep 2019 00:00:42 +0000   (2019, 9, 13, 0, 0, 42, 4, 256, 0)
# 9   Fri, 13 Sep 2019 00:00:22 +0000   (2019, 9, 13, 0, 0, 22, 4, 256, 0)
# 10  Thu, 12 Sep 2019 08:00:56 +0000   (2019, 9, 12, 8, 0, 56, 3, 255, 0)
# 11  Thu, 12 Sep 2019 02:00:20 +0000   (2019, 9, 12, 2, 0, 20, 3, 255, 0)
# 12  Thu, 12 Sep 2019 01:00:56 +0000   (2019, 9, 12, 1, 0, 56, 3, 255, 0)
# 13  Thu, 12 Sep 2019 01:00:35 +0000   (2019, 9, 12, 1, 0, 35, 3, 255, 0)
# 14  Thu, 12 Sep 2019 00:00:49 +0000   (2019, 9, 12, 0, 0, 49, 3, 255, 0)
# 15  Wed, 11 Sep 2019 22:00:17 +0000  (2019, 9, 11, 22, 0, 17, 2, 254, 0)
# 16  Wed, 11 Sep 2019 13:00:41 +0000  (2019, 9, 11, 13, 0, 41, 2, 254, 0)
# 17  Wed, 11 Sep 2019 13:00:38 +0000  (2019, 9, 11, 13, 0, 38, 2, 254, 0)
#
#    slash_comments                                            summary  \
# 0               0  Extracting Insights from the Shape of Complex ...
# 1               0  Mirroring to Build Trust in Digital Assistants...
# 2               0  Challenges in the Decentralised Web: The Masto...
# 3               0  Radar trends began as an internal resource for...
# 4               0  Universal Adversarial Triggers for Attacking a...
# 5               0  This is a keynote from the O&#8217;Reilly Arti...
# 6               0  This is a keynote highlight from the O&#8217;R...
# 7               0  This is a keynote highlight from the O&#8217;R...
# 8               0  This is a keynote highlight from the O&#8217;R...
# 9               0  This is a keynote highlight from the O&#8217;R...
# 10              0  The Philosophy and Practice of Bayesian Statis...
# 11              0  This is a keynote from the O&#8217;Reilly Arti...
# 12              0  This is a keynote highlight from the O&#8217;R...
# 13              0  This is a keynote highlight from the O&#8217;R...
# 14              0  People from across artificial intelligence (AI...
# 15              0  This is a keynote highlight from the O&#8217;R...
# 16              0  This is a keynote highlight from the O&#8217;R...
# 17              0  This is a keynote from the O&#8217;Reilly Arti...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
#
#                                                  tags  \
# 0   [{'term': 'Four Short Links', 'scheme': None, ...
# 1   [{'term': 'Four Short Links', 'scheme': None, ...
# 2   [{'term': 'Four Short Links', 'scheme': None, ...
# 3   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 4   [{'term': 'Four Short Links', 'scheme': None, ...
# 5   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 6   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 7   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 8   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 10  [{'term': 'Four Short Links', 'scheme': None, ...
# 11  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 12  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 13  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 14  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 15  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 16  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 17  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                                 title  \
# 0                 Four short links: 18 September 2019
# 1                 Four short links: 17 September 2019
# 2                 Four short links: 16 September 2019
# 3               Radar trends to watch: September 2019
# 4                 Four short links: 13 September 2019
# 5             Safe and smarter driving, powered by AI
# 6   On gradient-based methods for finding game-the...
# 7                             Accelerate with purpose
# 8   Practical insights into deep reinforcement lea...
# 9        Open-endedness: A new grand challenge for AI
# 10                Four short links: 12 September 2019
# 11     AI for ophthalmology: Doing what doctors can’t
# 12  Enabling AI’s potential through wafer-scale in...
# 13                               Getting from A to AI
# 14  Highlights from the O’Reilly Artificial Intell...
# 15             Going beyond fully supervised learning
# 16                          Developing AI responsibly
# 17                   Unlocking the value of your data
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
#
#                                        wfw_commentrss
# 0   https://www.oreilly.com/radar/four-short-links...
# 1   https://www.oreilly.com/radar/four-short-links...
# 2   https://www.oreilly.com/radar/four-short-links...
# 3   https://www.oreilly.com/radar/radar-trends-to-...
# 4   https://www.oreilly.com/radar/four-short-links...
# 5   https://www.oreilly.com/radar/safe-and-smarter...
# 6   https://www.oreilly.com/radar/on-gradient-base...
# 7   https://www.oreilly.com/radar/accelerate-with-...
# 8   https://www.oreilly.com/radar/practical-insigh...
# 9   https://www.oreilly.com/radar/open-endedness-a...
# 10  https://www.oreilly.com/radar/four-short-links...
# 11  https://www.oreilly.com/radar/ai-for-opthalmol...
# 12  https://www.oreilly.com/radar/enabling-ais-pot...
# 13  https://www.oreilly.com/radar/getting-from-a-t...
# 14  https://www.oreilly.com/radar/highlights-from-...
# 15  https://www.oreilly.com/radar/going-beyond-ful...
# 16  https://www.oreilly.com/radar/developing-ai-re...
# 17  https://www.oreilly.com/radar/unlocking-the-va...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#        author  entries
# 0  Mac Slocum       18

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
#do this after pandas lab

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
x = []
for i in range(len(oreily.entries)):
    x.append(oreily.entries[i].summary)
# Out:
# 18
