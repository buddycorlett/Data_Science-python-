# %%
import numpy as np
import pandas as pd

vehicles = pd.read_csv('vehicles.csv')

# %%
vehicles.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %%
vehicles['Year'].unique()
# Out:
# array([1984, 1985, 1987, 1997, 1998, 1999, 1995, 1996, 2001, 2002, 2003,
#        2000, 2004, 2013, 2014, 2015, 2016, 2017, 1986, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012])

# %%
vehicles[vehicles['Year'] == 2000]
# Out:
#                Make                 Model  Year  Engine Displacement  \
# 26            Acura                 3.2TL  2000                  3.2
# 34            Acura                 3.5RL  2000                  3.5
# 85            Acura               Integra  2000                  1.8
# 86            Acura               Integra  2000                  1.8
# 87            Acura               Integra  2000                  1.8
# 160           Acura                   NSX  2000                  3.0
# 161           Acura                   NSX  2000                  3.2
# 374    Aston Martin    DB-7 Vantage Coupe  2000                  5.9
# 375    Aston Martin    DB-7 Vantage Coupe  2000                  5.9
# 378    Aston Martin  DB-7 Vantage Volante  2000                  5.9
# 379    Aston Martin  DB-7 Vantage Volante  2000                  5.9
# 670            Audi                    A4  2000                  1.8
# 671            Audi                    A4  2000                  1.8
# ...

# %%
vehicles.dtypes
# Out:
# Make                        object
# Model                       object
# Year                         int64
# Engine Displacement        float64
# Cylinders                  float64
# Transmission                object
# Drivetrain                  object
# Vehicle Class               object
# Fuel Type                   object
# Fuel Barrels/Year          float64
# City MPG                     int64
# Highway MPG                  int64
# Combined MPG                 int64
# CO2 Emission Grams/Mile    float64
# Fuel Cost/Year               int64
# dtype: object

# %%
vehicles.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
vehicles.index
# Out:
# RangeIndex(start=0, stop=35952, step=1)

# %%
vehicles.index.values
# Out:
# array([    0,     1,     2, ..., 35949, 35950, 35951])

# %%
vehicles[0:10]
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
# 5             Acura          2.2CL/3.0CL  1997                  2.2
# 6             Acura          2.2CL/3.0CL  1997                  2.2
# 7             Acura          2.2CL/3.0CL  1997                  3.0
# 8             Acura          2.3CL/3.0CL  1998                  2.3
# 9             Acura          2.3CL/3.0CL  1998                  2.3
#
#    Cylinders     Transmission         Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# ...

# %%
vehicles[9:10]
# Out:
#     Make        Model  Year  Engine Displacement  Cylinders  Transmission  \
# 9  Acura  2.3CL/3.0CL  1998                  2.3        4.0  Manual 5-spd
#
#           Drivetrain    Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 9  Front-Wheel Drive  Subcompact Cars   Regular           13.73375        21
#
#    Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 9           29            24               370.291667            1400

# %%
vehicles[['Make', 'Model']][0:4]
# Out:
#          Make                Model
# 0  AM General    DJ Po Vehicle 2WD
# 1  AM General     FJ8c Post Office
# 2  AM General  Post Office DJ5 2WD
# 3  AM General  Post Office DJ8 2WD

# %%
vehicles[2:3]
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 2                 555.4375            2100

# %%
vehicles.iloc[2][3]
# Out:
# 2.5

# %%
vehicles['Engine Displacement'][2]
# Out:
# 2.5

# %%
vehicles.iloc[2][3:6]
# Out:
# Engine Displacement                2.5
# Cylinders                            4
# Transmission           Automatic 3-spd
# Name: 2, dtype: object

# %%
vehicles.loc[2:9]['Year']
# Out:
# 2    1985
# 3    1985
# 4    1987
# 5    1997
# 6    1997
# 7    1997
# 8    1998
# 9    1998
# Name: Year, dtype: int64

# %%
vehicles.loc[2:9, 'Year']
# Out:
# 2    1985
# 3    1985
# 4    1987
# 5    1997
# 6    1997
# 7    1997
# 8    1998
# 9    1998
# Name: Year, dtype: int64

# %%
# vehicles.loc[vehicles['Highway MPG'] > 1.5 * vehicles['City MPG']]

# %%
vehicles[vehicles['Highway MPG'] > 1.5 * vehicles['City MPG']]
# Out:
#                         Make            Model  Year  Engine Displacement  \
# 10                     Acura      2.3CL/3.0CL  1998                  3.0
# 13                     Acura      2.3CL/3.0CL  1999                  3.0
# 21                     Acura            3.2CL  2001                  3.2
# 22                     Acura            3.2CL  2002                  3.2
# 23                     Acura            3.2CL  2003                  3.2
# 24                     Acura            3.2CL  2003                  3.2
# 26                     Acura            3.2TL  2000                  3.2
# 27                     Acura            3.2TL  2001                  3.2
# 28                     Acura            3.2TL  2002                  3.2
# 29                     Acura            3.2TL  2003                  3.2
# 108                    Acura           Legend  1993                  3.2
# 200                    Acura              RLX  2014                  3.5
# ...

# %%
vehicles[vehicles['Year']==1985]
# Out:
#                               Make                   Model  Year  \
# 2                       AM General     Post Office DJ5 2WD  1985
# 3                       AM General     Post Office DJ8 2WD  1985
# 323                     Alfa Romeo               GT V6 2.5  1985
# 347                     Alfa Romeo      Spider Veloce 2000  1985
# 350    American Motors Corporation         Eagle 4DR Wagon  1985
# 351    American Motors Corporation         Eagle 4DR Wagon  1985
# 352    American Motors Corporation         Eagle 4DR Wagon  1985
# 426                   Aston Martin                 Lagonda  1985
# 437                   Aston Martin  Saloon/Vantage/Volante  1985
# 438                   Aston Martin  Saloon/Vantage/Volante  1985
# 546                           Audi                   4000s  1985
# 547                           Audi                   4000s  1985
# 548                           Audi           4000s quattro  1985
# ...
