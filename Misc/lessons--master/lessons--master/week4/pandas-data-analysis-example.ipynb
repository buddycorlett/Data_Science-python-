# %%
import pandas as pd
import numpy as np
student = pd.read_csv('student-mat.csv')

# %%
student.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
student.shape
# Out:
# (395, 33)

# %%
student.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [raw]
# # student['romantic'].astype('int64')

# %%
student_numeric = student._get_numeric_data()
student_numeric.head(5)
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %%
student.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
student_categorical = student.select_dtypes(include='object')
student_categorical.head(5)
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  yes         no     yes    yes      yes       no
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %%
student['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
student.groupby('sex').agg({'sex':len})
# Out:
#      sex
# sex
# F    208
# M    187

# %%
student.groupby('school').agg({'school':'count'})
# Out:
#         school
# school
# GP         349
# MS          46

# %% [markdown]
# ### breakdown of students who participate in extracurricular activities by sex

# %%
student.groupby(['sex', 'activities']).agg({'activities':'count'})
# Out:
#                 activities
# sex activities
# F   no                 112
#     yes                 96
# M   no                  82
#     yes                105

# %%
pd.crosstab(index=student.sex, columns=student.activities)
# Out:
# activities   no  yes
# sex
# F           112   96
# M            82  105

# %% [markdown]
# ### type of address vs. family size:

# %%
student.groupby(['address', 'famsize']).agg({'famsize':'count'})
# Out:
#                  famsize
# address famsize
# R       GT3           68
#         LE3           20
# U       GT3          213
#         LE3           94

# %%
pd.crosstab(index=student.address, columns=student.famsize)
# Out:
# famsize  GT3  LE3
# address
# R         68   20
# U        213   94

# %% [markdown]
# ### how many students improved their grade between the first and second period

# %%
student['improvement'] = np.where(student.G2 > student.G1, "improved", "did not improve")

# %%
student.groupby(['school', 'improvement']).agg({'improvement':'count'})
# Out:
#                         improvement
# school improvement
# GP     did not improve          228
#        improved                 121
# MS     did not improve           39
#        improved                   7

# %%
pd.crosstab(index=student.school, columns=student.improvement)
# Out:
# improvement  did not improve  improved
# school
# GP                       228       121
# MS                        39         7

# %%
student.pivot_table(index=["school", 'studytime'], columns=["sex"], values=["G3"])
# Out:
#                          G3
# sex                       F          M
# school studytime
# GP     1          10.652174  10.363636
#        2           9.363636  11.090909
#        3          10.590909  13.923077
#        4          11.000000  11.700000
# MS     1           5.250000   8.750000
#        2          10.428571  10.875000
#        3          11.571429  13.000000

# %%
student.pivot_table(index=["school"], columns=["sex", "studytime"], values=["G3"],fill_value=0)
# Out:
#                   G3                                                  \
# sex                F                                    M
# studytime          1          2          3   4          1          2
# school
# GP         10.652174   9.363636  10.590909  11  10.363636  11.090909
# MS          5.250000  10.428571  11.571429   0   8.750000  10.875000
#
#
# sex
# studytime          3     4
# school
# GP         13.923077  11.7
# MS         13.000000   0.0

# %%
student.pivot_table(index=["school"], columns=["sex", "studytime"], values=["G3"], fill_value=0, aggfunc='count')
# Out:
#            G3
# sex         F               M
# studytime   1   2   3   4   1   2   3   4
# school
# GP         23  99  44  17  66  77  13  10
# MS          4  14   7   0  12   8   1   0
