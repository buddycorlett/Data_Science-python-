# %%
import networkx as nx
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import warnings
from custom import load_data as cf

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [raw]
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'  # enable 2x retina images

# %%
G = cf.load_seventh_grader_network()

# %%
list(G.nodes(data=True))[0:5]
# Out:
# [(1, {'gender': 'male'}),
#  (2, {'gender': 'male'}),
#  (3, {'gender': 'male'}),
#  (4, {'gender': 'male'}),
#  (5, {'gender': 'male'})]

# %%
list(G.edges(data=True))[0:5]
# Out:
# [(1, 2, {'count': 1}),
#  (1, 3, {'count': 1}),
#  (1, 4, {'count': 2}),
#  (1, 5, {'count': 2}),
#  (1, 6, {'count': 3})]

# %% [markdown]
# In this artificial social network, the number of times the left student indicated that the right student was their favourite is stored in the "count" variable.

# %%
# G.node
# G.edges
len(G.node)
len(G.edges)
# Out:
# 376

# %%
from collections import Counter
mf_counts = Counter([d['gender'] for n, d in G.nodes(data=True)])
mf_counts
# Out:
# Counter({'male': 12, 'female': 17})

# %%
counts = [d['count'] for n1, n2, d in G.edges(data=True)]
maxcount = max(counts)
maxcount
# Out:
# 3

# %%
nx.draw(G, with_labels=True)

# %%
from nxviz import ArcPlot

a = ArcPlot(G, node_color='gender', node_grouping='gender')
a.draw()

# %%
G = cf.load_sociopatterns_network()

# %%
list(G.nodes(data=True))[0:5]
# Out:
# [(100, {'order': 100.0}),
#  (101, {'order': 101.0}),
#  (102, {'order': 102.0}),
#  (103, {'order': 103.0}),
#  (104, {'order': 104.0})]

# %%
list(G.edges(data=True))[0:5]
# Out:
# [(100, 101, {'weight': 2}),
#  (100, 102, {'weight': 1}),
#  (100, 103, {'weight': 4}),
#  (100, 104, {'weight': 3}),
#  (100, 105, {'weight': 10})]

# %%
list(G.neighbors(5))
# Out:
# [1, 3, 11, 12, 16, 19, 6, 7, 9]

# %%
hubs = {}
for node in G.node:
    hubs[node] = len(list(G.neighbors(node)))
hubs
# Out:
# {100: 29,
#  101: 13,
#  102: 16,
#  103: 26,
#  104: 17,
#  105: 23,
#  106: 15,
#  108: 15,
#  109: 21,
#  110: 19,
#  111: 6,
#  116: 7,
#  120: 22,
#  122: 32,
#  133: 19,
#  134: 16,
#  10: 10,
#  11: 14,
#  113: 23,
#  12: 16,
#  13: 13,
#  14: 11,
#  15: 7,
#  16: 16,
#  107: 12,
#  23: 8,
#  26: 6,
#  123: 19,
#  128: 15,
#  145: 7,
#  147: 13,
#  136: 7,
#  124: 20,
#  131: 10,
#  140: 16,
#  112: 26,
#  114: 5,
#  115: 15,
#  125: 21,
#  129: 17,
#  130: 13,
#  132: 25,
#  167: 8,
#  168: 15,
#  171: 28,
#  172: 14,
#  177: 23,
#  187: 12,
#  188: 30,
#  190: 13,
#  169: 22,
#  175: 20,
#  32: 9,
#  146: 18,
#  48: 10,
#  127: 17,
#  183: 24,
#  121: 19,
#  138: 6,
#  117: 24,
#  118: 21,
#  126: 19,
#  148: 31,
#  164: 22,
#  178: 18,
#  182: 13,
#  214: 14,
#  226: 16,
#  233: 21,
#  144: 20,
#  141: 8,
#  163: 14,
#  166: 11,
#  1: 5,
#  2: 8,
#  142: 13,
#  17: 6,
#  20: 4,
#  156: 21,
#  161: 34,
#  160: 18,
#  36: 8,
#  149: 19,
#  215: 19,
#  143: 8,
#  18: 4,
#  135: 1,
#  189: 2,
#  222: 7,
#  228: 17,
#  230: 26,
#  246: 2,
#  35: 6,
#  208: 14,
#  49: 5,
#  137: 4,
#  139: 4,
#  19: 13,
#  165: 24,
#  192: 13,
#  218: 14,
#  225: 15,
#  235: 43,
#  150: 14,
#  151: 13,
#  152: 17,
#  153: 17,
#  154: 23,
#  155: 16,
#  157: 17,
#  158: 17,
#  159: 13,
#  162: 15,
#  170: 16,
#  173: 22,
#  174: 22,
#  179: 23,
#  181: 33,
#  219: 34,
#  50: 33,
#  51: 50,
#  5: 9,
#  204: 18,
#  193: 13,
#  224: 9,
#  199: 28,
#  6: 8,
#  212: 12,
#  176: 18,
#  191: 7,
#  194: 10,
#  198: 26,
#  202: 24,
#  206: 23,
#  244: 17,
#  247: 13,
#  33: 7,
#  184: 12,
#  207: 25,
#  255: 8,
#  180: 9,
#  185: 6,
#  223: 9,
#  238: 22,
#  203: 1,
#  232: 23,
#  251: 5,
#  253: 3,
#  254: 3,
#  200: 18,
#  211: 12,
#  186: 1,
#  243: 10,
#  245: 8,
#  259: 25,
#  264: 28,
#  265: 34,
#  270: 11,
#  271: 4,
#  272: 47,
#  283: 24,
#  284: 23,
#  286: 7,
#  287: 26,
#  298: 25,
#  300: 20,
#  308: 15,
#  309: 14,
#  242: 12,
#  217: 7,
#  213: 11,
#  252: 9,
#  201: 15,
#  312: 17,
#  38: 13,
#  42: 26,
#  195: 43,
#  196: 22,
#  197: 25,
#  205: 14,
#  210: 16,
#  216: 13,
#  229: 25,
#  231: 25,
#  236: 17,
#  237: 24,
#  241: 17,
#  248: 8,
#  257: 28,
#  258: 24,
#  260: 25,
#  261: 27,
#  262: 23,
#  263: 21,
#  266: 17,
#  267: 17,
#  277: 8,
#  278: 11,
#  291: 26,
#  292: 33,
#  299: 29,
#  323: 4,
#  209: 14,
#  227: 23,
#  239: 22,
#  240: 27,
#  74: 23,
#  75: 14,
#  76: 9,
#  77: 10,
#  250: 8,
#  21: 2,
#  22: 2,
#  220: 2,
#  281: 24,
#  288: 31,
#  221: 10,
#  249: 8,
#  268: 8,
#  234: 10,
#  319: 8,
#  321: 8,
#  331: 11,
#  343: 7,
#  334: 11,
#  335: 19,
#  336: 7,
#  353: 12,
#  360: 6,
#  361: 13,
#  362: 8,
#  294: 31,
#  296: 26,
#  313: 1,
#  314: 23,
#  39: 15,
#  40: 8,
#  24: 4,
#  25: 3,
#  47: 11,
#  71: 16,
#  73: 11,
#  256: 2,
#  302: 7,
#  30: 5,
#  282: 24,
#  295: 24,
#  297: 27,
#  285: 21,
#  293: 27,
#  290: 3,
#  315: 8,
#  301: 20,
#  305: 13,
#  307: 15,
#  274: 5,
#  326: 8,
#  327: 13,
#  269: 3,
#  70: 14,
#  72: 11,
#  306: 11,
#  318: 22,
#  324: 6,
#  328: 15,
#  333: 15,
#  338: 8,
#  339: 14,
#  340: 17,
#  341: 20,
#  345: 25,
#  346: 16,
#  347: 14,
#  348: 19,
#  351: 14,
#  354: 16,
#  355: 15,
#  356: 20,
#  357: 14,
#  358: 15,
#  359: 27,
#  365: 11,
#  369: 8,
#  371: 15,
#  373: 8,
#  376: 16,
#  377: 14,
#  379: 16,
#  385: 10,
#  27: 5,
#  28: 8,
#  29: 4,
#  273: 5,
#  275: 6,
#  41: 17,
#  44: 18,
#  276: 3,
#  303: 4,
#  279: 5,
#  280: 9,
#  317: 7,
#  52: 4,
#  304: 9,
#  289: 2,
#  311: 2,
#  370: 1,
#  325: 9,
#  310: 5,
#  320: 4,
#  3: 7,
#  31: 2,
#  316: 3,
#  329: 14,
#  378: 18,
#  380: 14,
#  381: 12,
#  382: 11,
#  383: 8,
#  384: 13,
#  386: 16,
#  389: 20,
#  322: 3,
#  330: 12,
#  372: 8,
#  332: 12,
#  337: 5,
#  366: 6,
#  368: 6,
#  349: 7,
#  363: 10,
#  350: 7,
#  344: 9,
#  34: 3,
#  37: 17,
#  342: 7,
#  367: 20,
#  374: 14,
#  375: 9,
#  387: 9,
#  395: 4,
#  399: 12,
#  400: 17,
#  404: 10,
#  63: 8,
#  69: 5,
#  4: 4,
#  402: 6,
#  352: 9,
#  364: 7,
#  388: 4,
#  391: 3,
#  394: 4,
#  66: 11,
#  392: 2,
#  396: 2,
#  406: 5,
#  407: 8,
#  408: 9,
#  393: 7,
#  403: 8,
#  43: 10,
#  62: 6,
#  65: 5,
#  8: 12,
#  45: 8,
#  410: 4,
#  78: 15,
#  390: 1,
#  409: 2,
#  95: 25,
#  9: 14,
#  58: 13,
#  64: 9,
#  397: 4,
#  398: 1,
#  405: 4,
#  401: 3,
#  84: 10,
#  85: 14,
#  54: 8,
#  55: 8,
#  57: 6,
#  92: 2,
#  56: 11,
#  60: 7,
#  67: 12,
#  88: 14,
#  93: 22,
#  87: 20,
#  46: 3,
#  80: 5,
#  81: 14,
#  90: 15,
#  53: 2,
#  7: 7,
#  59: 5,
#  61: 5,
#  68: 3,
#  97: 17,
#  86: 6,
#  94: 20,
#  79: 1,
#  119: 1,
#  82: 2,
#  83: 3,
#  89: 4,
#  91: 21,
#  96: 15,
#  99: 14,
#  98: 1}

# %%
import pandas as pd
hubs1 = pd.DataFrame.from_dict(hubs, orient = 'index').reset_index()
hubs1.columns = ['Node','Neighbors']
hubs1.head()
hubs1.sort_values('Neighbors', ascending= False).head(10)
# Out:
#      Node  Neighbors
# 120    51         50
# 159   272         47
# 102   235         43
# 176   195         43
# 156   265         34
# 79    161         34
# 118   219         34
# 117   181         33
# 199   292         33
# 119    50         33

# %%
hubs1['Centrality'] = hubs1['Neighbors']/hubs1.shape[0]
hubs1.head()
# Out:
#    Node  Neighbors  Centrality
# 0   100         29    0.070732
# 1   101         13    0.031707
# 2   102         16    0.039024
# 3   103         26    0.063415
# 4   104         17    0.041463

# %%
list(nx.degree_centrality(G).items())[0:5]
# Out:
# [(100, 0.07090464547677261),
#  (101, 0.03178484107579462),
#  (102, 0.039119804400977995),
#  (103, 0.06356968215158924),
#  (104, 0.04156479217603912)]

# %% [markdown]
# ### Shortest Path Algorithm - Breadth First Search

# %%
def pathExists(node1, node2, G):
    visited_nodes = set()
    queue = [node1]

    for node in queue:
        neighbors = list(G.neighbors(node))
#         print("Neighbors for Node",node,"are",neighbors)
        if node2 in neighbors:
            print('Path exists between nodes {0} and {1}'.format(node1, node2))
            return True
        else:
            visited_nodes.add(node)
            queue.extend([n for n in neighbors if n not in visited_nodes])
#             print(queue)
        
    print('Path does not exist between nodes {0} and {1}'.format(node1, node2))
    return False

# %%
pathExists(1, 10, G)
# Out:
# Path exists between nodes 1 and 10
# True

# %%
nx.has_path(G, 400, 1)
# Out:
# True

# %%
nx.shortest_path(G, 4, 400)
# Out:
# [4, 90, 111, 112, 132, 230, 335, 400]

# %%
def graphShortestPath(node1, node2, G):
    if nx.has_path(G, node1, node2):
        nodes = nx.shortest_path(G, node1, node2)
        newG = G.subgraph(nodes)
        nx.draw(newG,with_labels=True)
        
    else:
        raise Exception('Path does not exist between nodes {0} and {1}.'.format(source, target))  
graphShortestPath(4,400,G)
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# ### Draw Neighbor Nodes

# %%
def draw_neighbor_edges1(G, node):
    neighbors = G.neighbors(node)
    newG = G.subgraph(neighbors)
    nx.draw(newG,with_labels=True)
draw_neighbor_edges1(G, 19)
# nx.draw(newG, with_labels=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
def extract_neighbor_edges2(G, node):
    neighbors = G.neighbors(node)
    newG = nx.Graph()
    
    for neighbor in neighbors:
        if (node, neighbor) in G.edges() or (neighbor, node) in G.edges():
            newG.add_edge(node, neighbor)

    return newG

fig = plt.figure(1)
newG = extract_neighbor_edges2(G, 19)
nx.draw(newG, with_labels=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
list(G.neighbors(19))
# Out:
# [14, 16, 17, 18, 20, 38, 42, 74, 75, 76, 77, 5, 9]

# %% [markdown]
# # Cliques

# %%
G = cf.load_physicians_network()

# %%
list(nx.find_cliques(G))
# Out:
# [[1, 2],
#  [1, 3],
#  [1, 4, 5, 6],
#  [1, 7],
#  [1, 72],
#  [2, 41],
#  [2, 10],
#  [2, 11, 40],
#  [2, 11, 39],
#  [2, 42, 110],
#  [3, 67, 42],
#  [3, 101],
#  [3, 9, 41],
#  [3, 9, 11],
#  [3, 112],
#  [3, 91],
#  [4, 6, 32],
#  [4, 6, 109],
#  [4, 104],
#  [4, 74, 116],
#  [4, 46, 55],
#  [4, 22],
#  [4, 55, 32],
#  [4, 59],
#  [5, 38, 69],
#  [5, 39],
#  [5, 9, 66],
#  [5, 9, 69],
#  [5, 9, 8],
#  [5, 9, 85],
#  [5, 9, 89],
#  [5, 45],
#  [5, 91],
#  [6, 31, 109],
#  [7, 102],
#  [8, 9, 10],
#  [8, 9, 11],
#  [8, 12, 11],
#  [9, 70, 41],
#  [9, 70, 10],
#  [9, 40, 66],
#  [9, 40, 11, 89],
#  [9, 40, 85],
#  [9, 40, 69],
#  [9, 41, 69],
#  [9, 10, 89],
#  [9, 82, 85],
#  [9, 53, 89],
#  [10, 67, 89],
#  [10, 102, 94],
#  [10, 108],
#  [10, 77, 89],
#  [10, 77, 45],
#  [10, 77, 38],
#  [10, 83, 91],
#  [10, 54],
#  [10, 91, 94],
#  [11, 65, 15],
#  [11, 39, 12],
#  [11, 40, 12, 15],
#  [11, 40, 94],
#  [11, 43, 15],
#  [11, 79],
#  [11, 87],
#  [11, 28, 12],
#  [11, 93],
#  [12, 97, 19],
#  [12, 97, 100],
#  [12, 97, 47],
#  [12, 67, 66],
#  [12, 100, 28],
#  [12, 40, 66],
#  [12, 40, 75],
#  [12, 40, 69, 73],
#  [12, 108],
#  [12, 19, 75],
#  [13, 47, 16, 17],
#  [13, 47, 43],
#  [13, 15, 43],
#  [13, 15, 16, 22],
#  [13, 15, 18, 65],
#  [13, 15, 18, 74, 14],
#  [13, 15, 59],
#  [13, 17, 16, 19],
#  [13, 17, 16, 22],
#  [13, 17, 74, 14],
#  [13, 86, 18],
#  [13, 92, 16, 22],
#  [13, 30],
#  [14, 56, 57],
#  [14, 56, 18],
#  [14, 51],
#  [14, 74, 57, 101],
#  [14, 75],
#  [15, 96, 16],
#  [15, 96, 54],
#  [15, 74, 60],
#  [15, 74, 54],
#  [15, 16, 49],
#  [15, 16, 34, 29],
#  [15, 16, 60],
#  [15, 81],
#  [15, 83],
#  [15, 23, 33, 34],
#  [15, 23, 34, 29],
#  [15, 23, 80],
#  [15, 23, 22],
#  [15, 23, 54, 40, 37],
#  [15, 23, 54, 115],
#  [15, 59, 60],
#  [15, 60, 33],
#  [15, 62],
#  [16, 19, 63],
#  [16, 27],
#  [16, 63, 29],
#  [17, 64, 47],
#  [17, 84],
#  [18, 35, 74],
#  [18, 28],
#  [19, 36, 63],
#  [19, 63, 75],
#  [20, 24],
#  [20, 25, 112],
#  [20, 25, 21, 117, 95],
#  [20, 25, 21, 23],
#  [20, 22, 23],
#  [21, 36],
#  [21, 37, 25, 23],
#  [21, 38],
#  [23, 102, 40],
#  [23, 111, 25],
#  [23, 51, 63],
#  [23, 63, 29],
#  [24, 32, 92],
#  [24, 32, 93],
#  [24, 35, 92],
#  [24, 39],
#  [24, 75],
#  [24, 81],
#  [24, 90],
#  [25, 98, 111],
#  [25, 41],
#  [25, 27],
#  [25, 93, 112],
#  [26, 109, 33],
#  [26, 109, 31],
#  [26, 48, 29],
#  [26, 48, 31],
#  [26, 62],
#  [26, 27, 30],
#  [26, 28, 32],
#  [26, 28, 33],
#  [26, 28, 31],
#  [27, 54],
#  [27, 55, 46],
#  [27, 55, 30],
#  [28, 100, 31],
#  [28, 44],
#  [28, 71],
#  [29, 104],
#  [29, 105],
#  [29, 106],
#  [29, 113],
#  [29, 53, 63],
#  [29, 57],
#  [30, 104],
#  [30, 99, 84, 55],
#  [30, 100],
#  [31, 41, 109],
#  [31, 60],
#  [31, 49, 48],
#  [31, 49, 100],
#  [32, 47],
#  [32, 55, 92],
#  [33, 35, 34],
#  [33, 35, 109],
#  [35, 98],
#  [35, 100, 74],
#  [35, 105],
#  [36, 106],
#  [36, 44, 43],
#  [36, 44, 76],
#  [36, 45, 43, 47],
#  [36, 45, 76],
#  [36, 45, 63],
#  [36, 78, 76],
#  [36, 79, 47],
#  [38, 101, 69],
#  [38, 78, 86],
#  [38, 58],
#  [39, 78],
#  [40, 102, 94],
#  [40, 71, 73, 54],
#  [40, 75, 89],
#  [41, 68, 69],
#  [41, 68, 70],
#  [41, 109, 69],
#  [41, 94],
#  [41, 103],
#  [42, 67, 72, 103],
#  [42, 74],
#  [42, 110, 58],
#  [42, 83],
#  [43, 46, 44],
#  [44, 64],
#  [44, 48],
#  [45, 72],
#  [45, 80],
#  [45, 93],
#  [46, 84, 82],
#  [46, 84, 55, 87],
#  [46, 60],
#  [47, 97, 79],
#  [48, 50],
#  [48, 51],
#  [48, 52, 116],
#  [49, 68],
#  [49, 103],
#  [50, 89],
#  [51, 104],
#  [51, 73],
#  [51, 114],
#  [52, 63],
#  [53, 68],
#  [53, 78],
#  [53, 84],
#  [54, 105],
#  [55, 94],
#  [55, 86],
#  [56, 58],
#  [57, 68],
#  [58, 104],
#  [58, 88],
#  [58, 91],
#  [58, 99],
#  [59, 61],
#  [60, 113],
#  [60, 114],
#  [61, 87],
#  [62, 64],
#  [62, 63],
#  [63, 81],
#  [63, 86],
#  [67, 103, 98],
#  [69, 98, 111],
#  [69, 101, 87],
#  [69, 79],
#  [69, 93],
#  [71, 72, 73],
#  [72, 78],
#  [73, 99, 84],
#  [74, 97, 106],
#  [74, 97, 100],
#  [74, 101, 87],
#  [74, 108],
#  [75, 80],
#  [75, 77, 89],
#  [75, 103],
#  [77, 81],
#  [78, 88],
#  [78, 85],
#  [78, 87],
#  [81, 82],
#  [82, 83],
#  [84, 107, 87],
#  [86, 106],
#  [87, 105],
#  [89, 90],
#  [91, 98, 94],
#  [92, 107, 108],
#  [93, 113],
#  [97, 98],
#  [101, 102],
#  [102, 112],
#  [118, 137, 122],
#  [118, 121, 120],
#  [118, 121, 131],
#  [118, 119],
#  [123, 120],
#  [123, 124, 160, 126],
#  [123, 124, 125],
#  [126, 137],
#  [126, 121, 160, 136],
#  [126, 121, 161, 162],
#  [126, 119, 160],
#  [127, 130, 144, 141],
#  [127, 130, 151],
#  [127, 133, 128, 156],
#  [127, 133, 128, 141],
#  [127, 133, 128, 157],
#  [127, 133, 131],
#  [127, 133, 142],
#  [127, 134, 132, 128],
#  [127, 134, 132, 125],
#  [127, 134, 132, 144],
#  [127, 137, 142],
#  [127, 141, 128, 129],
#  [127, 141, 128, 145],
#  [127, 144, 132, 156],
#  [127, 145, 128, 132],
#  [127, 145, 148],
#  [127, 149, 148],
#  [127, 149, 157, 128],
#  [127, 149, 157, 158],
#  [127, 150, 156],
#  [127, 150, 151, 155],
#  [127, 150, 151, 148],
#  [127, 119, 129, 128],
#  [127, 119, 129, 158],
#  [127, 119, 125],
#  [127, 121, 161, 120],
#  [127, 121, 161, 162],
#  [127, 121, 161, 125],
#  [127, 121, 131, 151],
#  [127, 121, 131, 129],
#  [127, 121, 131, 159],
#  [127, 121, 132, 128, 129],
#  [127, 121, 132, 120],
#  [127, 121, 132, 125, 142],
#  [127, 121, 136, 120],
#  [127, 121, 148, 151],
#  [127, 121, 158, 129],
#  [127, 155, 129],
#  [127, 155, 162],
#  [127, 156, 128, 132],
#  [127, 157, 136],
#  [135, 136, 121],
#  [135, 137],
#  [138, 144, 130, 140],
#  [138, 144, 130, 141],
#  [138, 121, 136],
#  [138, 121, 129, 128],
#  [138, 121, 129, 158],
#  [138, 121, 140],
#  [138, 141, 128, 129],
#  [139, 162],
#  [139, 134],
#  [139, 136],
#  [139, 151],
#  [139, 152],
#  [143, 161],
#  [143, 134, 144],
#  [143, 137],
#  [143, 145],
#  [143, 151],
#  [146, 128, 145],
#  [146, 128, 163],
#  [147, 145],
#  [147, 153],
#  [147, 155, 151],
#  [152, 128, 164],
#  [152, 128, 133],
#  [152, 128, 149],
#  [152, 153, 154, 133],
#  [152, 150],
#  [153, 148],
#  [163, 128, 121, 132],
#  [163, 128, 149],
#  [164, 131],
#  [165, 128],
#  [165, 162],
#  [165, 159],
#  [166, 168, 167],
#  [166, 169, 170, 173],
#  [166, 169, 172],
#  [166, 171, 172],
#  [166, 171, 167],
#  [167, 178],
#  [167, 194, 192],
#  [167, 194, 171],
#  [167, 194, 190],
#  [167, 194, 168],
#  [167, 204],
#  [167, 174, 171],
#  [168, 185],
#  [168, 194, 200, 179],
#  [168, 194, 197, 203, 179],
#  [168, 194, 197, 196],
#  [168, 194, 198, 203],
#  [168, 194, 198, 196],
#  [169, 197, 173],
#  [170, 193, 192],
#  [170, 193, 185, 202],
#  [170, 193, 188],
#  [170, 204, 185],
#  [170, 173, 188],
#  [170, 187, 185],
#  [170, 189, 192],
#  [170, 189, 202],
#  [171, 194, 196, 197],
#  [171, 194, 196, 199],
#  [171, 174, 175],
#  [172, 200],
#  [172, 198],
#  [174, 176, 177],
#  [174, 176, 175],
#  [175, 183, 191],
#  [175, 190, 176],
#  [176, 198, 186],
#  [177, 196, 197],
#  [177, 206],
#  [178, 179],
#  [178, 180, 181],
#  [179, 188],
#  [182, 186, 184, 183],
#  [182, 186, 185, 187],
#  [182, 188, 184],
#  [182, 189],
#  [183, 195, 192],
#  [183, 195, 184, 186],
#  [183, 195, 184, 202],
#  [183, 204, 184],
#  [183, 191, 192],
#  [183, 191, 202],
#  [184, 193, 195, 186],
#  [184, 193, 195, 202],
#  [184, 193, 188],
#  [185, 193, 195, 186],
#  [185, 193, 195, 202],
#  [185, 193, 191, 202],
#  [187, 194, 200, 201],
#  [187, 194, 200, 199],
#  [187, 194, 197],
#  [190, 194, 197],
#  [191, 193, 192],
#  [192, 193, 195],
#  [192, 194, 201],
#  [192, 194, 198],
#  [192, 206],
#  [194, 205, 197],
#  [194, 205, 198],
#  [195, 197],
#  [198, 202],
#  [207, 209, 208, 210, 211],
#  [207, 209, 213],
#  [207, 212],
#  [208, 210, 228, 225, 220, 216],
#  [208, 210, 228, 225, 220, 209, 221],
#  [208, 210, 228, 227, 216],
#  [208, 210, 228, 211, 216],
#  [208, 210, 228, 211, 209],
#  [208, 210, 223, 216, 211],
#  [208, 210, 223, 216, 220],
#  [208, 210, 223, 221, 220],
#  [208, 226, 209, 220, 221],
#  [208, 229, 209, 220],
#  [208, 229, 227],
#  [208, 229, 231],
#  [209, 217, 211, 228],
#  [209, 217, 221, 218],
#  [209, 217, 221, 220, 225, 228],
#  [209, 217, 221, 220, 226],
#  [209, 218, 213],
#  [209, 213, 229],
#  [209, 213, 214],
#  [209, 214, 210],
#  [210, 233, 216, 220],
#  [210, 219, 220, 228, 221],
#  [210, 214, 216],
#  [211, 232],
#  [211, 240, 234],
#  [213, 230],
#  [213, 233, 234],
#  [213, 233, 235],
#  [213, 233, 229],
#  [213, 240, 234],
#  [213, 240, 235],
#  [213, 214, 215],
#  [213, 215, 218],
#  [213, 223],
#  [215, 226],
#  [215, 231, 237, 236],
#  [215, 231, 237, 238],
#  [216, 235, 233],
#  [216, 230],
#  [217, 219, 220, 221, 226],
#  [217, 219, 220, 221, 228],
#  [217, 222, 218],
#  [219, 240, 234],
#  [219, 240, 235],
#  [219, 226, 224, 220, 221],
#  [219, 226, 235],
#  [220, 224, 223, 221],
#  [220, 232],
#  [220, 233, 229],
#  [224, 227],
#  [229, 241],
#  [229, 231, 233],
#  [230, 232, 231],
#  [231, 232, 237, 236],
#  [231, 232, 237, 238],
#  [231, 233, 235],
#  [232, 239, 237],
#  [235, 241]]

# %%
newG = G.subgraph(list(nx.find_cliques(G))[2])
nx.draw(newG, with_labels=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# # Bike Stations

# %%
stations = pd.read_csv('Divvy_Stations_2013.csv', parse_dates=['online date'], encoding='utf-8')
stations.head()
# Out:
#    id                        name   latitude  longitude  dpcapacity  landmark  \
# 0   5      State St & Harrison St  41.873958 -87.627739          19        30
# 1  13  Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19        66
# 2  14         Morgan St & 18th St  41.858086 -87.651073          15       163
# 3  15        Racine Ave & 18th St  41.858181 -87.656487          15       164
# 4  16         Wood St & North Ave  41.910329 -87.672516          15       223
#
#   online date
# 0  2013-06-28
# 1  2013-06-28
# 2  2013-06-28
# 3  2013-06-28
# 4  2013-08-12

# %%
trips = pd.read_csv('Divvy_Trips_2013.csv',parse_dates=['starttime', 'stoptime'])
trips.head(5)
# Out:
#    trip_id           starttime            stoptime  bikeid  tripduration  \
# 0     4118 2013-06-27 12:11:00 2013-06-27 12:16:00     480           316
# 1     4275 2013-06-27 14:44:00 2013-06-27 14:45:00      77            64
# 2     4291 2013-06-27 14:58:00 2013-06-27 15:05:00      77           433
# 3     4316 2013-06-27 15:06:00 2013-06-27 15:09:00      77           123
# 4     4342 2013-06-27 15:13:00 2013-06-27 15:27:00      77           852
#
#    from_station_id           from_station_name  to_station_id  \
# 0               85       Michigan Ave & Oak St             28
# 1               32  Racine Ave & Congress Pkwy             32
# 2               32  Racine Ave & Congress Pkwy             19
# 3               19       Loomis St & Taylor St             19
# 4               19       Loomis St & Taylor St             55
#
#                     to_station_name  usertype gender  birthday
# 0        Larrabee St & Menomonee St  Customer    NaN       NaN
# 1        Racine Ave & Congress Pkwy  Customer    NaN       NaN
# 2             Loomis St & Taylor St  Customer    NaN       NaN
# 3             Loomis St & Taylor St  Customer    NaN       NaN
# 4  Halsted St & James M Rochford St  Customer    NaN       NaN

# %%
x = trips.groupby(['from_station_id', 'to_station_id']).agg('count').reset_index()
x
x = x[['from_station_id', 'to_station_id', 'trip_id']]
x.columns = ['FromStation', 'ToStation', 'NumberofTrips']
print(x.head())
numberOfTrips= x['NumberofTrips']
# Out:
#    FromStation  ToStation  NumberofTrips
# 0            5          5            232
# 1            5         13              1
# 2            5         14             15
# 3            5         15              9
# 4            5         16              4

# %% [markdown]
# ### Now we will make the graph from the data that we have

# %%
stations.to_dict('records')[0]
# Out:
# {'id': 5,
#  'name': 'State St & Harrison St',
#  'latitude': 41.87395806,
#  'longitude': -87.62773949,
#  'dpcapacity': 19,
#  'landmark': 30,
#  'online date': Timestamp('2013-06-28 00:00:00')}

# %%
G = nx.DiGraph()
for item in stations.to_dict('records'):
    node_id = item['id']
    G.add_node(node_id, name = item['name'], lat = item['latitude'], long = item['longitude'])

# %%
list(G.nodes(data=True))[0:1]
# Out:
# [(5,
#   {'name': 'State St & Harrison St',
#    'lat': 41.87395806,
#    'long': -87.62773949})]

# %%
x.to_dict('records')[0]
# Out:
# {'FromStation': 5, 'ToStation': 5, 'NumberofTrips': 232}

# %%
for d in x.to_dict('records'):
    G.add_edge(d['FromStation'], d['ToStation'], count=d['NumberofTrips'])

# %%
# list(G.edges(data=True))[0:10]

# %%
# Filter the edges to just those with more than 100 trips.
G_filtered = G.copy()
for u, v, d in G.edges(data=True):
    if d['count'] < 100:
        G_filtered.remove_edge(u,v)
        
G_filtered.edges
# Out:
# OutEdgeView([(5, 5), (5, 36), (5, 37), (5, 49), (5, 59), (5, 68), (5, 75), (5, 76), (5, 77), (5, 81), (5, 90), (5, 97), (5, 174), (13, 13), (13, 34), (13, 67), (13, 115), (13, 153), (13, 220), (14, 14), (16, 58), (17, 17), (17, 69), (19, 22), (19, 241), (20, 48), (20, 58), (21, 21), (21, 36), (21, 73), (21, 75), (21, 134), (22, 19), (22, 22), (22, 32), (22, 57), (23, 31), (23, 85), (24, 24), (24, 25), (24, 26), (24, 35), (24, 43), (24, 47), (24, 51), (24, 52), (24, 75), (24, 76), (24, 85), (24, 90), (24, 91), (24, 97), (24, 99), (24, 173), (24, 199), (25, 24), (25, 25), (25, 26), (25, 31), (25, 34), (25, 35), (25, 43), (25, 44), (25, 45), (25, 47), (25, 52), (25, 76), (25, 85), (25, 90), (25, 91), (25, 97), (25, 99), (25, 110), (25, 126), (25, 173), (25, 177), (25, 181), (26, 24), (26, 25), (26, 26), (26, 34), (26, 35), (26, 37), (26, 43), (26, 44), (26, 45), (26, 47), (26, 49), (26, 50), (26, 51), (26, 52), (26, 59), (26, 75), (26, 76), (26, 81), (26, 85), (26, 90), (26, 91), (26, 94), (26, 97), (26, 99), (26, 126), (26, 173), (26, 177), (26, 181), (26, 192), (26, 199), (26, 211), (28, 28), (28, 118), (29, 29), (29, 48), (29, 69), (30, 69), (31, 25), (31, 31), (31, 48), (31, 54), (31, 66), (31, 75), (31, 77), (31, 91), (31, 173), (32, 75), (33, 26), (33, 33), (33, 36), (33, 51), (33, 52), (33, 59), (33, 75), (33, 76), (33, 77), (33, 81), (33, 90), (33, 97), (33, 134), (33, 174), (34, 13), (34, 24), (34, 25), (34, 26), (34, 34), (34, 35), (34, 67), (34, 76), (34, 85), (34, 94), (34, 99), (34, 126), (34, 157), (34, 177), (35, 5), (35, 24), (35, 25), (35, 26), (35, 33), (35, 34), (35, 35), (35, 37), (35, 43), (35, 44), (35, 45), (35, 47), (35, 51), (35, 52), (35, 59), (35, 76), (35, 85), (35, 90), (35, 97), (35, 99), (35, 110), (35, 126), (35, 141), (35, 157), (35, 173), (35, 176), (35, 177), (35, 181), (35, 194), (35, 195), (35, 196), (35, 199), (35, 211), (35, 255), (35, 268), (35, 284), (36, 5), (36, 21), (36, 25), (36, 26), (36, 33), (36, 35), (36, 36), (36, 37), (36, 43), (36, 44), (36, 45), (36, 47), (36, 49), (36, 52), (36, 59), (36, 66), (36, 73), (36, 74), (36, 76), (36, 77), (36, 81), (36, 90), (36, 91), (36, 97), (36, 100), (36, 110), (36, 134), (36, 140), (36, 174), (36, 181), (37, 5), (37, 25), (37, 26), (37, 35), (37, 36), (37, 37), (37, 43), (37, 44), (37, 47), (37, 50), (37, 51), (37, 52), (37, 59), (37, 75), (37, 76), (37, 77), (37, 81), (37, 90), (37, 91), (37, 97), (37, 110), (37, 140), (37, 174), (37, 176), (37, 181), (37, 192), (42, 42), (42, 59), (43, 25), (43, 26), (43, 33), (43, 35), (43, 36), (43, 43), (43, 45), (43, 47), (43, 48), (43, 50), (43, 51), (43, 52), (43, 59), (43, 75), (43, 76), (43, 77), (43, 85), (43, 90), (43, 91), (43, 97), (43, 110), (43, 174), (43, 255), (43, 287), (44, 5), (44, 24), (44, 25), (44, 26), (44, 33), (44, 36), (44, 37), (44, 44), (44, 47), (44, 51), (44, 52), (44, 59), (44, 66), (44, 75), (44, 77), (44, 90), (44, 91), (44, 110), (44, 174), (44, 192), (44, 199), (45, 25), (45, 26), (45, 35), (45, 36), (45, 37), (45, 43), (45, 45), (45, 52), (45, 59), (45, 62), (45, 75), (45, 76), (45, 90), (45, 97), (45, 168), (45, 174), (45, 255), (46, 46), (46, 53), (46, 85), (46, 91), (46, 174), (47, 25), (47, 26), (47, 33), (47, 35), (47, 36), (47, 37), (47, 43), (47, 44), (47, 47), (47, 49), (47, 50), (47, 56), (47, 66), (47, 74), (47, 75), (47, 76), (47, 77), (47, 81), (47, 85), (47, 90), (47, 91), (47, 174), (47, 192), (48, 20), (48, 31), (48, 47), (48, 48), (48, 53), (48, 58), (48, 60), (48, 74), (48, 75), (48, 77), (48, 91), (48, 100), (48, 110), (48, 144), (48, 174), (48, 176), (48, 181), (48, 192), (49, 5), (49, 26), (49, 36), (49, 47), (49, 49), (49, 50), (49, 51), (49, 52), (49, 59), (49, 72), (49, 75), (49, 77), (49, 90), (49, 91), (49, 100), (49, 110), (49, 140), (49, 168), (49, 174), (49, 176), (49, 192), (49, 283), (50, 21), (50, 37), (50, 43), (50, 47), (50, 49), (50, 50), (50, 52), (50, 53), (50, 59), (50, 72), (50, 75), (50, 77), (50, 91), (50, 100), (50, 110), (50, 168), ...
