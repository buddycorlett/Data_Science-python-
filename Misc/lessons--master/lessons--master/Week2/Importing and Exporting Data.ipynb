# %% [raw]
# Delimited files for eg
#
#
#     Comma-separated variable (CSV) files
#     Tab-delimited files
#     Pipe-delimited files

# %% [markdown]
# ### Importing and Exporting Delimited Files

# %%
import pandas as pd
data = pd.read_csv('/Users/himanshuaggarwal//ironhack-my-content/himanshu/data/vehicles/vehicles.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
# pd.read

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(1)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            27
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950

# %% [raw]
# Exporting data as a different csv file after making some changes

# %%
data['Combined MPG'] = data['Combined MPG'] + 10
data.to_csv('/Users/himanshuaggarwal//ironhack-my-content/himanshu/data/vehicles/vehiclesCOPIED.csv')

# %%
data2 = pd.read_csv('/Users/himanshuaggarwal//ironhack-my-content/himanshu/data/vehicles/vehiclesCOPIED.csv')
data2.head(3)
# Out:
#    Unnamed: 0        Make                Model  Year  Engine Displacement  \
# 0           0  AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1           1  AM General     FJ8c Post Office  1984                  4.2
# 2           2  AM General  Post Office DJ5 2WD  1985                  2.5
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            27
# 1   Regular          25.354615        13           13            23
# 2   Regular          20.600625        16           17            26
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %% [raw]
# Tab Separated files

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/Users/himanshuaggarwal/ironhack-my-content/himanshu/data/vehicles/vehicles_tab.txt', sep='\t')
data.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %%
# Export tab-delimited file
data.to_csv('/Users/himanshuaggarwal//ironhack-my-content/himanshu/data/vehicles/vehicles_tabCOPIED.txt', sep='\t', index=False)
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [raw]
# Pipe delimited file

# %%
data = pd.read_csv('/Users/himanshuaggarwal//ironhack-my-content/himanshu/data/vehicles/vehicles_pipe.txt', sep='|')
data.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %%
# Export pipe-delimited file
data.to_csv('vehicles/vehicles_pipeCOPIED.txt', sep='|', index=False)

# %% [markdown]
# ### Importing and Exporting Excel

# %%
data = pd.read_excel('/Users/himanshuaggarwal/ironhack-my-content/himanshu/data/vehicles/vehicles.xlsx')
data.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5          4
# 1  AM General     FJ8c Post Office  1984                  4.2          6
# 2  AM General  Post Office DJ5 2WD  1985                  2.5          4
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %%
#data.to_excel('vehicles/vehicles.xlsx', index=False)

# %% [markdown]
# ### Importing and Exporting JSON

# %%
data = pd.read_json('/Users/himanshuaggarwal/ironhack-my-content/himanshu/data/vehicles/vehicles.json', orient='records')
data.head(3)
# Out:
#    CO2 Emission Grams/Mile  City MPG  Combined MPG  Cylinders  \
# 0               522.764706        18            17          4
# 1               683.615385        13            13          6
# 2               555.437500        16            16          4
#
#          Drivetrain  Engine Displacement  Fuel Barrels/Year  Fuel Cost/Year  \
# 0     2-Wheel Drive                  2.5          19.388824            1950
# 1     2-Wheel Drive                  4.2          25.354615            2550
# 2  Rear-Wheel Drive                  2.5          20.600625            2100
#
#   Fuel Type  Highway MPG        Make                Model     Transmission  \
# 0   Regular           17  AM General    DJ Po Vehicle 2WD  Automatic 3-spd
# 1   Regular           13  AM General     FJ8c Post Office  Automatic 3-spd
# 2   Regular           17  AM General  Post Office DJ5 2WD  Automatic 3-spd
#
#                  Vehicle Class  Year
# 0  Special Purpose Vehicle 2WD  1984
# ...

# %%
data.to_json('/Users/himanshuaggarwal/ironhack-my-content/himanshu/data/vehicles/vehiclesCOPIED.json', orient='records')

# %%
json = {
  "cms_prescription_counts": {
    "CEPHALEXIN": 23, 
    "AMOXICILLIN": 52, 
    "HYDROCODONE-ACETAMINOPHEN": 28},
  "provider_variables": {
    "settlement_type": "non-urban", 
    "generic_rx_count": 103, 
    "specialty": "General Practice", 
    "years_practicing": 7, 
    "gender": "M", 
    "region": "South", 
    "brand_name_rx_count": 0}, 
  "npi": "1992715205"}

# %%
data = pd.DataFrame.from_dict(json, orient ='columns')
# data = pd.DataFrame.from_dict(json, orient ='index')

# %%
data.head()
# Out:
#                            cms_prescription_counts provider_variables  \
# AMOXICILLIN                                   52.0                NaN
# CEPHALEXIN                                    23.0                NaN
# HYDROCODONE-ACETAMINOPHEN                     28.0                NaN
# brand_name_rx_count                            NaN                  0
# gender                                         NaN                  M
#
#                                   npi
# AMOXICILLIN                1992715205
# CEPHALEXIN                 1992715205
# HYDROCODONE-ACETAMINOPHEN  1992715205
# brand_name_rx_count        1992715205
# gender                     1992715205
