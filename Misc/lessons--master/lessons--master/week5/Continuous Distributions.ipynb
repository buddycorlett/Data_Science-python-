# %%
import numpy as np
from scipy.stats import uniform
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
x = np.linspace(0,1, 100)

ax.plot(x, uniform.pdf(x))

# %%
fig, ax = plt.subplots(1, 1)
a=1
b=3
x = np.linspace(a,b, 100)
y = uniform.pdf(x, a, b)
ax.plot(x, y)

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.2042964  2.42047419 2.86239778 2.22618273 2.64935935 2.05464608
#  2.66770602 2.0602403  2.30074241 2.93700992]

# %%
import math
from scipy.stats import norm
normal = norm(0, math.sqrt(9)) 
print(normal.pdf(4))
print(normal.cdf(2))       
print(normal.rvs()) 
fig, ax = plt.subplots(1, 1)
x = np.linspace(-3,3,1000)
y = norm.pdf(x)
ax.plot(x,y)
plt.show()
ax.hist(norm.rvs(100), density=True, histtype='stepfilled', alpha=0.2)
plt.show()
# Out:
# 0.05467002489199788
# 0.7475074624530771
# 1.9902173168465538

# %%
from scipy.stats import expon
exp = expon(1) 
print(exp.pdf(4))
print(exp.cdf(2))       
print(exp.rvs()) 
x = np.linspace(0,10,100)
y = expon.pdf(x)
fig, ax = plt.subplots(1, 1)
ax.plot(x,y)
# Out:
# 0.049787068367863944
# 0.6321205588285577
# 1.1225805165453657
