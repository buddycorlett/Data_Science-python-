# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Graph

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

#resize your graph

plt.figure(figsize=(5,3),dpi = 150)

##Create the plot 
plt.plot(x,y, label='2x', color = 'green', linewidth=2, marker='.', linestyle = '--',markersize = 10,markeredgecolor = 'blue')
# plt.plot(x,y,'b.--', markersize = 10)##shorthand notation

##Label Axis
plt.title('Our Graph', fontdict={'fontname': 'Times New Roman', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

##Create second line with x^2 and format that line with different markers/colors
plt.plot(x2[:5],x2[:5]**2, label='x^2', color = 'red', linewidth = 2, marker = '.', linestyle = '--', markersize = 10, markeredgecolor = 'black')
plt.plot(x2[4:],x2[4:]**2, color = 'red', linewidth = 2, marker = '.', markersize = 10, markeredgecolor = 'black')

##give a np array from 0 to 4.5 in intervals of .5
x2 = np.arange(0,4.6,.5)
print(x2)

#set the values on the ticks
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10,22])

##show legend and show graph
plt.legend()
plt.show()

##save graph in folder(problems still)
plt.savefig('mygraph.png')
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5]

# %% [markdown]
# # Barcharts EX

# %%
labels = ['A','B','C',]
values = [1,4,2,]

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']

# for bar in bars:
#     bar.set_hatch(patterns.pop(0))
bars[0].set_hatch('/')
bars[1].set_hatch('O')
bars[2].set_hatch('*')

plt.figure(figsize=(6,4))

plt.show()
