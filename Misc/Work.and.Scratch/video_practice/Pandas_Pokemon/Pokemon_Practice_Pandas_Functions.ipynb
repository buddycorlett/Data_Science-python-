# %%
import pandas as pd 

df = pd.read_csv('pokemon_data.csv')

# df.head()
# df.tail(10)

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# df_xlsx.head()

# df_tab = pd.read_csv('pokemon_data.txt', delimiter='\t')
# df_tab.head()

# print(df.columns)

# print(df['Name'])
# print(df['Name'][0:5])
# print(df[['Name','Type 1','HP']])

# df.head()
# print(df.iloc[1])
# print(df.iloc[0:4])

# print(df.iloc[2,1])

# for index,row in df.iterrows():
#     print(index,row)
    
df.loc[df['Type 1'] == "Fire"] #Giving you the Type 1 equal to "Fire"
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# df.sort_values(['Type 1', 'HP'], ascending = False)## Sort by Type 1 and then HP 
df.sort_values(['Type 1', 'HP'], ascending = [1,0])## Sort by Type 1 and then HP and it will ascend on Type 1 and descend on HP
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 447  402               Kricketune    Bug       NaN  77      85       51
# 220  205               Forretress    Bug     Steel  75      90      140
# 602  542                 Leavanny    Bug     Grass  75     103       80
# 717  649                 Genesect    Bug     Steel  71     120       95
# 54    49                 Venomoth    Bug    Poison  70      65       60
# 132  123                  Scyther    Bug    Flying  70     110       80
# ...

# %%
df.head(5)
df['Total'] = df['HP']+ df['Attack']+ df['Defense']+ df['Sp. Atk']+ df['Sp. Def']+ df['Speed']

df = df.sort_values(['Total'], ascending = False)
df = df.drop(columns=['Total'])

# %%
# df.head()
# df["Total"] = df.iloc[:,4:10].sum(axis=1) ##First colon means all the rows and the second means add 4:9 together using the .sum
# df.head()

# cols = list(df.columns.values)

df.to_csv("Modified.csv", index = False)
# df.to_excel('modified.xlsx'index = False)
df.to_csv('modified.txt', index = False, sep = '\t')

# %%
new_df = df.loc[((df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')) & (df['HP'] > 100)]
new_df
# Out:
#        #       Name Type 1  Type 2  Speed  Generation  Legendary   HP  Attack  \
# 741  673     Gogoat  Grass     NaN     68           6      False  123     100
# 652  591  Amoonguss  Grass  Poison     30           5      False  114      85
#
#      Defense  Sp. Atk  Sp. Def
# 741       62       97       81
# 652       70       85       80

# %%
new_df.reset_index()
# Out:
#    index    #       Name Type 1  Type 2  Speed  Generation  Legendary   HP  \
# 0    741  673     Gogoat  Grass     NaN     68           6      False  123
# 1    652  591  Amoonguss  Grass  Poison     30           5      False  114
#
#    Attack  Defense  Sp. Atk  Sp. Def
# 0     100       62       97       81
# 1      85       70       85       80

# %%
import re
##Filter Mega
df.loc[df['Name'].str.contains('Mega')]
# df.loc[~df['Name'].str.contains('Mega')] this ~ means not
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]#This will ignore case because of the flags=re.I
# Out:
#        #                       Name Type 1    Type 2  Speed  Generation  \
# 270  250                      Ho-oh   Fire    Flying     90           2
# 7      6  CharizardMega Charizard X   Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y   Fire    Flying    100           1
# 279  257      BlazikenMega Blaziken   Fire  Fighting    100           3
# 275  254      SceptileMega Sceptile  Grass    Dragon    145           3
# 3      3      VenusaurMega Venusaur  Grass    Poison     80           1
# 551  492           ShayminSky Forme  Grass    Flying    127           4
# 550  492          ShayminLand Forme  Grass       NaN    100           4
# 542  485                    Heatran   Fire     Steel     77           4
# 799  721                  Volcanion   Fire     Water     70           6
# 511  460    AbomasnowMega Abomasnow  Grass       Ice     30           4
# 263  244                      Entei   Fire       NaN    100           2
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I,regex=True)] #this will find any names which contain a pi then letters
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I,regex=True)] #the ^ will specify the start of line
# Out:
#        #                 Name    Type 1    Type 2  Speed  Generation  \
# 137  127    PinsirMega Pinsir       Bug    Flying    105           1
# 23    18  PidgeotMega Pidgeot    Normal    Flying    121           1
# 136  127               Pinsir       Bug       NaN     85           1
# 22    18              Pidgeot    Normal    Flying    101           1
# 239  221            Piloswine       Ice    Ground     50           2
# 558  499              Pignite      Fire  Fighting     55           5
# 21    17            Pidgeotto    Normal    Flying     71           1
# 30    25              Pikachu  Electric       NaN     90           1
# 438  393               Piplup     Water       NaN     40           4
# 219  204               Pineco       Bug       NaN     15           2
# 578  519               Pidove    Normal    Flying     43           5
# 20    16               Pidgey    Normal    Flying     56           1
# 186  172                Pichu  Electric       NaN     60           2
#
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1']= 'Flamer' ##So if Type 1 is equal to fire then change type 1 to flamer

# %%
##Changing multiple parameters

df.loc[df[Total]]
# Out:
#        #                       Name  Type 1    Type 2  Speed  Generation  \
# 270  250                      Ho-oh  Flamer    Flying     90           2
# 7      6  CharizardMega Charizard X  Flamer    Dragon    100           1
# 8      6  CharizardMega Charizard Y  Flamer    Flying    100           1
# 279  257      BlazikenMega Blaziken  Flamer  Fighting    100           3
# 542  485                    Heatran  Flamer     Steel     77           4
# 799  721                  Volcanion  Flamer     Water     70           6
# 263  244                      Entei  Flamer       NaN    100           2
# 158  146                    Moltres  Flamer    Flying     90           1
# 354  323      CameruptMega Camerupt  Flamer    Ground     20           3
# 64    59                   Arcanine  Flamer       NaN     95           1
# 518  467                  Magmortar  Flamer       NaN     83           4
# 616  555         DarmanitanZen Mode  Flamer   Psychic     55           5
# ...

# %%
#Aggregate Statistics
df = pd.read_csv('modified.csv')

# %%
df['Total'] = df['Speed']+df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']

# %%
df_new = df[['#', 'Name','Type 1', 'Type 2','Total', 'Speed','HP', 'Attack','Defense', 'Sp. Atk', 'Sp. Def', 'Generation', 'Legendary']]
df_new
# Out:
#        #                     Name    Type 1    Type 2  Total  Speed   HP  \
# 0    384    RayquazaMega Rayquaza    Dragon    Flying    780    115  105
# 1    150      MewtwoMega Mewtwo X   Psychic  Fighting    780    130  106
# 2    150      MewtwoMega Mewtwo Y   Psychic       NaN    780    140  106
# 3    382      KyogrePrimal Kyogre     Water       NaN    770     90  100
# 4    383    GroudonPrimal Groudon    Ground      Fire    770     90  100
# 5    493                   Arceus    Normal       NaN    720    120  120
# 6    380        LatiasMega Latias    Dragon   Psychic    700    110   80
# 7    719      DiancieMega Diancie      Rock     Fairy    700    110   50
# 8    248  TyranitarMega Tyranitar      Rock      Dark    700     71  100
# 9    381        LatiosMega Latios    Dragon   Psychic    700    110   80
# 10   445    GarchompMega Garchomp    Dragon    Ground    700     92  108
# 11   376  MetagrossMega Metagross     Steel   Psychic    700    110   80
# ...

# %%
df_new.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)
# Out:
#                    #       Total       Speed         HP      Attack  \
# Type 1
# Dragon    474.375000  550.531250   83.031250  83.312500  112.125000
# Fighting  363.851852  416.444444   66.074074  69.851852   96.777778
# Ground    356.281250  437.500000   63.906250  73.781250   95.750000
# Rock      392.727273  453.750000   55.909091  65.363636   92.863636
# Steel     442.851852  487.703704   55.259259  65.222222   92.703704
# Dark      461.354839  445.741935   76.161290  66.806452   88.387097
# Fire      327.403846  458.076923   74.442308  69.903846   84.769231
# Flying    677.750000  485.000000  102.500000  70.750000   78.750000
# Poison    251.785714  399.142857   63.571429  67.250000   74.678571
# Water     303.089286  430.455357   65.964286  72.062500   74.151786
# Ghost     486.500000  439.562500   64.343750  64.437500   73.781250
# Normal    319.173469  401.683673   71.551020  77.275510   73.469388
# Grass     344.871429  421.142857   61.928571  67.271429   73.214286
# ...

# %%
df_new.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total  Speed   HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug        69    69      52     69     69   69      69       69       69
# Dark       31    31      21     31     31   31      31       31       31
# Dragon     32    32      21     32     32   32      32       32       32
# Electric   44    44      17     44     44   44      44       44       44
# Fairy      17    17       2     17     17   17      17       17       17
# Fighting   27    27       7     27     27   27      27       27       27
# Fire       52    52      24     52     52   52      52       52       52
# Flying      4     4       2      4      4    4       4        4        4
# Ghost      32    32      22     32     32   32      32       32       32
# Grass      70    70      37     70     70   70      70       70       70
# Ground     32    32      19     32     32   32      32       32       32
# Ice        24    24      11     24     24   24      24       24       24
# ...

# %%
df.groupby(['Type 1', 'Type 2']).count()['#']
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
#                       ..
# Rock      Fighting     1
#           Flying       4
#           Grass        2
#           Ground       6
#           Ice          2
# ...

# %%
##load in 5 rows at a time for df in
